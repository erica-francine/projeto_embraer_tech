# %%
from random import randint, choice
import mysql.connector

# %%
conexao = mysql.connector.connect(
    host='localhost',
    user='root',
    password='admin',
    database='custos_transporte'
)

# %%
cursor = conexao.cursor()

# Pegando todos os id_compra_materia_prima do MySQL da tabela compra_materia_prima e armazenando em uma variável
cursor.execute("SELECT id_compra FROM compra_materia_prima")
compra_materia_prima = cursor.fetchall()

# Pegando todos os cod_materia_prima do MySQL da tabela materia_prima e armazenando em uma variável
cursor.execute("SELECT cod_materia_prima FROM materia_prima")
materia_prima = cursor.fetchall()

# Pegando todos os id_modelo do MySQL da tabela modelo_aviao e armazenando em uma variável
cursor.execute("SELECT id_aviao FROM producao_aviao")
producao_aviao = cursor.fetchall()

# %%
cursor = conexao.cursor()

# Função que vai gerar 800 registros aleatórios e inserir no MySQL na tabela item_compra
def item_compra():
    nums_seq_existentes = set()
      
    for _ in range(800):
        num_seq = randint(0, 800)
        
        while num_seq in nums_seq_existentes:
            num_seq = randint(0, 800)

            nums_seq_existentes.add(num_seq)
            
            print(f"Tentando inserir num_seq={num_seq}")
            
        quantidade = randint(5, 50)

        # Pegando IDs aleatórios das tabelas
        compra_materia_prima_id_compra = choice(compra_materia_prima)[0]
        materia_prima_cod_materia_prima = choice(materia_prima)[0]
        producao_aviao_id_aviao = choice(producao_aviao)[0]

        # Pegando IDs das tabelas compra_materia_prima, materia_prima e producao_aviao
        cursor.execute("SELECT id_compra FROM compra_materia_prima WHERE id_compra = %s", (compra_materia_prima_id_compra,))
        compra_materia_prima_id_compra = cursor.fetchone()[0]

        cursor.execute("SELECT cod_materia_prima FROM materia_prima WHERE cod_materia_prima = %s", (materia_prima_cod_materia_prima,))
        materia_prima_cod_materia_prima = cursor.fetchone()[0]

        cursor.execute("SELECT id_aviao FROM producao_aviao WHERE id_aviao = %s", (producao_aviao_id_aviao,))
        producao_aviao_id_aviao = cursor.fetchone()[0]

        # Inserindo dados na tabela
        try:
            insert_query = "INSERT INTO item_compra (num_seq, compra_materia_prima_id_compra, materia_prima_cod_materia_prima, quantidade, producao_aviao_id_aviao) VALUES (%s, %s, %s, %s, %s);"
            data = (num_seq, compra_materia_prima_id_compra, materia_prima_cod_materia_prima, quantidade, producao_aviao_id_aviao)
            cursor.execute(insert_query, data)
        
            conexao.commit()
    
            print(f"Inserção bem-sucedida para num_seq={num_seq}")
        except mysql.connector.Error as err:
            if err.errno == mysql.connector.errorcode.ER_DUP_ENTRY:
                print(f"Duplicidade encontrada para num_seq={num_seq}")
            else:
                print(f"Erro ao inserir: {err}")

# Chamando a função para gerar os registros
item_compra()

# Fechando a conexão
cursor.close()
conexao.close()
# Out:
# Inserção bem-sucedida para num_seq=645
# Inserção bem-sucedida para num_seq=490
# Inserção bem-sucedida para num_seq=755
# Inserção bem-sucedida para num_seq=363
# Inserção bem-sucedida para num_seq=635
# Inserção bem-sucedida para num_seq=147
# Inserção bem-sucedida para num_seq=634
# Inserção bem-sucedida para num_seq=359
# Inserção bem-sucedida para num_seq=251
# Inserção bem-sucedida para num_seq=182
# Inserção bem-sucedida para num_seq=580
# Inserção bem-sucedida para num_seq=325
# Duplicidade encontrada para num_seq=325
# Inserção bem-sucedida para num_seq=275
# Inserção bem-sucedida para num_seq=680
# Inserção bem-sucedida para num_seq=355
# Inserção bem-sucedida para num_seq=371
# Inserção bem-sucedida para num_seq=542
# Inserção bem-sucedida para num_seq=382
# Inserção bem-sucedida para num_seq=721
# Inserção bem-sucedida para num_seq=617
# Inserção bem-sucedida para num_seq=33
# Inserção bem-sucedida para num_seq=595
# Inserção bem-sucedida para num_seq=203
# Inserção bem-sucedida para num_seq=736
# Inserção bem-sucedida para num_seq=761
# Inserção bem-sucedida para num_seq=91
# Inserção bem-sucedida para num_seq=472
# Inserção bem-sucedida para num_seq=346
# Inserção bem-sucedida para num_seq=108
# Inserção bem-sucedida para num_seq=441
# Inserção bem-sucedida para num_seq=593
# Inserção bem-sucedida para num_seq=339
# Inserção bem-sucedida para num_seq=128
# Inserção bem-sucedida para num_seq=360
# Inserção bem-sucedida para num_seq=100
# Inserção bem-sucedida para num_seq=621
# Inserção bem-sucedida para num_seq=446
# Inserção bem-sucedida para num_seq=344
# Inserção bem-sucedida para num_seq=188
# Inserção bem-sucedida para num_seq=254
# Inserção bem-sucedida para num_seq=377
# Inserção bem-sucedida para num_seq=122
# Inserção bem-sucedida para num_seq=343
# Inserção bem-sucedida para num_seq=554
# Duplicidade encontrada para num_seq=275
# Inserção bem-sucedida para num_seq=661
# Inserção bem-sucedida para num_seq=719
# Inserção bem-sucedida para num_seq=117
# Inserção bem-sucedida para num_seq=558
# Inserção bem-sucedida para num_seq=718
# Inserção bem-sucedida para num_seq=269
# Inserção bem-sucedida para num_seq=60
# Inserção bem-sucedida para num_seq=710
# Inserção bem-sucedida para num_seq=688
# Inserção bem-sucedida para num_seq=394
# Inserção bem-sucedida para num_seq=513
# Inserção bem-sucedida para num_seq=400
# Inserção bem-sucedida para num_seq=763
# Inserção bem-sucedida para num_seq=782
# Inserção bem-sucedida para num_seq=594
# Inserção bem-sucedida para num_seq=568
# Inserção bem-sucedida para num_seq=106
# Inserção bem-sucedida para num_seq=749
# Inserção bem-sucedida para num_seq=89
# Inserção bem-sucedida para num_seq=644
# Inserção bem-sucedida para num_seq=768
# Duplicidade encontrada para num_seq=346
# Inserção bem-sucedida para num_seq=614
# Inserção bem-sucedida para num_seq=655
# Inserção bem-sucedida para num_seq=282
# Duplicidade encontrada para num_seq=710
# Inserção bem-sucedida para num_seq=136
# Inserção bem-sucedida para num_seq=798
# Inserção bem-sucedida para num_seq=605
# Inserção bem-sucedida para num_seq=218
# Inserção bem-sucedida para num_seq=37
# Inserção bem-sucedida para num_seq=323
# Inserção bem-sucedida para num_seq=205
# Inserção bem-sucedida para num_seq=198
# Inserção bem-sucedida para num_seq=127
# Inserção bem-sucedida para num_seq=398
# Inserção bem-sucedida para num_seq=370
# Inserção bem-sucedida para num_seq=728
# Inserção bem-sucedida para num_seq=368
# Inserção bem-sucedida para num_seq=502
# Inserção bem-sucedida para num_seq=557
# Duplicidade encontrada para num_seq=205
# Duplicidade encontrada para num_seq=218
# Inserção bem-sucedida para num_seq=6
# Inserção bem-sucedida para num_seq=194
# Inserção bem-sucedida para num_seq=547
# Inserção bem-sucedida para num_seq=607
# Inserção bem-sucedida para num_seq=563
# Inserção bem-sucedida para num_seq=685
# Inserção bem-sucedida para num_seq=692
# Inserção bem-sucedida para num_seq=352
# Inserção bem-sucedida para num_seq=523
# Inserção bem-sucedida para num_seq=167
# Inserção bem-sucedida para num_seq=509
# Inserção bem-sucedida para num_seq=765
# Inserção bem-sucedida para num_seq=744
# Inserção bem-sucedida para num_seq=444
# Inserção bem-sucedida para num_seq=510
# Inserção bem-sucedida para num_seq=583
# Inserção bem-sucedida para num_seq=535
# Inserção bem-sucedida para num_seq=316
# Inserção bem-sucedida para num_seq=20
# Inserção bem-sucedida para num_seq=713
# Inserção bem-sucedida para num_seq=412
# Inserção bem-sucedida para num_seq=678
# Inserção bem-sucedida para num_seq=546
# Duplicidade encontrada para num_seq=763
# Inserção bem-sucedida para num_seq=684
# Inserção bem-sucedida para num_seq=733
# Duplicidade encontrada para num_seq=563
# Inserção bem-sucedida para num_seq=337
# Inserção bem-sucedida para num_seq=224
# Duplicidade encontrada para num_seq=398
# Duplicidade encontrada para num_seq=339
# Inserção bem-sucedida para num_seq=34
# Inserção bem-sucedida para num_seq=14
# Inserção bem-sucedida para num_seq=184
# Duplicidade encontrada para num_seq=14
# Inserção bem-sucedida para num_seq=348
# Inserção bem-sucedida para num_seq=682
# Inserção bem-sucedida para num_seq=672
# Inserção bem-sucedida para num_seq=329
# Inserção bem-sucedida para num_seq=403
# Duplicidade encontrada para num_seq=607
# Inserção bem-sucedida para num_seq=330
# Inserção bem-sucedida para num_seq=695
# Inserção bem-sucedida para num_seq=258
# Duplicidade encontrada para num_seq=682
# Inserção bem-sucedida para num_seq=11
# Inserção bem-sucedida para num_seq=545
# Inserção bem-sucedida para num_seq=304
# Inserção bem-sucedida para num_seq=15
# Duplicidade encontrada para num_seq=323
# Inserção bem-sucedida para num_seq=240
# Duplicidade encontrada para num_seq=583
# Inserção bem-sucedida para num_seq=268
# Inserção bem-sucedida para num_seq=756
# Inserção bem-sucedida para num_seq=753
# Inserção bem-sucedida para num_seq=386
# Inserção bem-sucedida para num_seq=517
# Inserção bem-sucedida para num_seq=656
# Inserção bem-sucedida para num_seq=308
# Inserção bem-sucedida para num_seq=599
# Inserção bem-sucedida para num_seq=328
# Inserção bem-sucedida para num_seq=750
# Inserção bem-sucedida para num_seq=521
# Inserção bem-sucedida para num_seq=657
# Inserção bem-sucedida para num_seq=190
# Inserção bem-sucedida para num_seq=531
# Inserção bem-sucedida para num_seq=691
# Duplicidade encontrada para num_seq=713
# Inserção bem-sucedida para num_seq=288
# Inserção bem-sucedida para num_seq=126
# Duplicidade encontrada para num_seq=599
# Inserção bem-sucedida para num_seq=673
# Inserção bem-sucedida para num_seq=87
# Inserção bem-sucedida para num_seq=717
# Inserção bem-sucedida para num_seq=262
# Duplicidade encontrada para num_seq=386
# Inserção bem-sucedida para num_seq=378
# Duplicidade encontrada para num_seq=678
# Duplicidade encontrada para num_seq=37
# Inserção bem-sucedida para num_seq=97
# Inserção bem-sucedida para num_seq=432
# Inserção bem-sucedida para num_seq=723
# Inserção bem-sucedida para num_seq=260
# Inserção bem-sucedida para num_seq=271
# Inserção bem-sucedida para num_seq=52
# Inserção bem-sucedida para num_seq=2
# Inserção bem-sucedida para num_seq=671
# Inserção bem-sucedida para num_seq=239
# Inserção bem-sucedida para num_seq=742
# Inserção bem-sucedida para num_seq=227
# Inserção bem-sucedida para num_seq=155
# Inserção bem-sucedida para num_seq=420
# Inserção bem-sucedida para num_seq=197
# Inserção bem-sucedida para num_seq=301
# Inserção bem-sucedida para num_seq=766
# Inserção bem-sucedida para num_seq=659
# Inserção bem-sucedida para num_seq=497
# Inserção bem-sucedida para num_seq=129
# Inserção bem-sucedida para num_seq=541
# Duplicidade encontrada para num_seq=34
# Inserção bem-sucedida para num_seq=159
# Inserção bem-sucedida para num_seq=172
# Inserção bem-sucedida para num_seq=508
# Inserção bem-sucedida para num_seq=18
# Duplicidade encontrada para num_seq=308
# Inserção bem-sucedida para num_seq=242
# Inserção bem-sucedida para num_seq=740
# Duplicidade encontrada para num_seq=713
# Inserção bem-sucedida para num_seq=471
# Inserção bem-sucedida para num_seq=265
# Inserção bem-sucedida para num_seq=668
# Duplicidade encontrada para num_seq=227
# Inserção bem-sucedida para num_seq=525
# Inserção bem-sucedida para num_seq=667
# Inserção bem-sucedida para num_seq=560
# Inserção bem-sucedida para num_seq=79
# Inserção bem-sucedida para num_seq=559
# Duplicidade encontrada para num_seq=719
# Inserção bem-sucedida para num_seq=358
# Inserção bem-sucedida para num_seq=658
# Duplicidade encontrada para num_seq=136
# Inserção bem-sucedida para num_seq=500
# Inserção bem-sucedida para num_seq=676
# Inserção bem-sucedida para num_seq=774
# Duplicidade encontrada para num_seq=554
# Inserção bem-sucedida para num_seq=389
# Inserção bem-sucedida para num_seq=666
# Duplicidade encontrada para num_seq=242
# Inserção bem-sucedida para num_seq=654
# Inserção bem-sucedida para num_seq=9
# Inserção bem-sucedida para num_seq=449
# Inserção bem-sucedida para num_seq=165
# Inserção bem-sucedida para num_seq=84
# Duplicidade encontrada para num_seq=766
# Inserção bem-sucedida para num_seq=164
# Inserção bem-sucedida para num_seq=780
# Duplicidade encontrada para num_seq=634
# Inserção bem-sucedida para num_seq=732
# Inserção bem-sucedida para num_seq=550
# Inserção bem-sucedida para num_seq=539
# Inserção bem-sucedida para num_seq=256
# Inserção bem-sucedida para num_seq=652
# Inserção bem-sucedida para num_seq=291
# Inserção bem-sucedida para num_seq=55
# Inserção bem-sucedida para num_seq=336
# Inserção bem-sucedida para num_seq=413
# Duplicidade encontrada para num_seq=580
# Inserção bem-sucedida para num_seq=101
# Duplicidade encontrada para num_seq=352
# Inserção bem-sucedida para num_seq=36
# Inserção bem-sucedida para num_seq=322
# Duplicidade encontrada para num_seq=256
# Inserção bem-sucedida para num_seq=220
# Inserção bem-sucedida para num_seq=158
# Inserção bem-sucedida para num_seq=135
# Inserção bem-sucedida para num_seq=486
# Inserção bem-sucedida para num_seq=482
# Duplicidade encontrada para num_seq=688
# Inserção bem-sucedida para num_seq=726
# Inserção bem-sucedida para num_seq=174
# Inserção bem-sucedida para num_seq=27
# Duplicidade encontrada para num_seq=268
# Inserção bem-sucedida para num_seq=302
# Inserção bem-sucedida para num_seq=418
# Inserção bem-sucedida para num_seq=247
# Inserção bem-sucedida para num_seq=426
# Inserção bem-sucedida para num_seq=305
# Inserção bem-sucedida para num_seq=170
# Inserção bem-sucedida para num_seq=722
# Duplicidade encontrada para num_seq=37
# Duplicidade encontrada para num_seq=753
# Inserção bem-sucedida para num_seq=627
# Inserção bem-sucedida para num_seq=373
# Inserção bem-sucedida para num_seq=625
# Inserção bem-sucedida para num_seq=727
# Inserção bem-sucedida para num_seq=754
# Duplicidade encontrada para num_seq=348
# Duplicidade encontrada para num_seq=672
# Inserção bem-sucedida para num_seq=144
# Inserção bem-sucedida para num_seq=195
# Inserção bem-sucedida para num_seq=351
# Duplicidade encontrada para num_seq=742
# Inserção bem-sucedida para num_seq=735
# Duplicidade encontrada para num_seq=645
# Duplicidade encontrada para num_seq=545
# Inserção bem-sucedida para num_seq=257
# Inserção bem-sucedida para num_seq=703
# Inserção bem-sucedida para num_seq=552
# Duplicidade encontrada para num_seq=547
# Duplicidade encontrada para num_seq=260
# Inserção bem-sucedida para num_seq=137
# Duplicidade encontrada para num_seq=535
# Inserção bem-sucedida para num_seq=362
# Inserção bem-sucedida para num_seq=632
# Inserção bem-sucedida para num_seq=390
# Duplicidade encontrada para num_seq=304
# Inserção bem-sucedida para num_seq=4
# Duplicidade encontrada para num_seq=20
# Inserção bem-sucedida para num_seq=443
# Inserção bem-sucedida para num_seq=113
# Duplicidade encontrada para num_seq=260
# Inserção bem-sucedida para num_seq=93
# Inserção bem-sucedida para num_seq=784
# Duplicidade encontrada para num_seq=678
# Inserção bem-sucedida para num_seq=392
# Inserção bem-sucedida para num_seq=215
# Inserção bem-sucedida para num_seq=572
# Duplicidade encontrada para num_seq=257
# Inserção bem-sucedida para num_seq=287
# Inserção bem-sucedida para num_seq=232
# Inserção bem-sucedida para num_seq=10
# Duplicidade encontrada para num_seq=79
# Inserção bem-sucedida para num_seq=771
# Inserção bem-sucedida para num_seq=620
# Inserção bem-sucedida para num_seq=148
# Duplicidade encontrada para num_seq=330
# Inserção bem-sucedida para num_seq=630
# Duplicidade encontrada para num_seq=727
# Inserção bem-sucedida para num_seq=769
# Duplicidade encontrada para num_seq=535
# Inserção bem-sucedida para num_seq=590
# Inserção bem-sucedida para num_seq=615
# Inserção bem-sucedida para num_seq=597
# Duplicidade encontrada para num_seq=634
# Inserção bem-sucedida para num_seq=494
# Duplicidade encontrada para num_seq=510
# Inserção bem-sucedida para num_seq=112
# Inserção bem-sucedida para num_seq=310
# Inserção bem-sucedida para num_seq=83
# Inserção bem-sucedida para num_seq=125
# Inserção bem-sucedida para num_seq=255
# Duplicidade encontrada para num_seq=673
# Duplicidade encontrada para num_seq=607
# Inserção bem-sucedida para num_seq=452
# Inserção bem-sucedida para num_seq=58
# Inserção bem-sucedida para num_seq=779
# Inserção bem-sucedida para num_seq=694
# Duplicidade encontrada para num_seq=652
# Inserção bem-sucedida para num_seq=571
# Duplicidade encontrada para num_seq=288
# Inserção bem-sucedida para num_seq=407
# Duplicidade encontrada para num_seq=717
# Inserção bem-sucedida para num_seq=214
# Inserção bem-sucedida para num_seq=176
# Duplicidade encontrada para num_seq=531
# Duplicidade encontrada para num_seq=155
# Inserção bem-sucedida para num_seq=454
# Inserção bem-sucedida para num_seq=50
# Inserção bem-sucedida para num_seq=200
# Inserção bem-sucedida para num_seq=448
# Duplicidade encontrada para num_seq=765
# Inserção bem-sucedida para num_seq=776
# Duplicidade encontrada para num_seq=523
# Duplicidade encontrada para num_seq=205
# Inserção bem-sucedida para num_seq=803
# Inserção bem-sucedida para num_seq=660
# Duplicidade encontrada para num_seq=568
# Duplicidade encontrada para num_seq=721
# Inserção bem-sucedida para num_seq=376
# Inserção bem-sucedida para num_seq=604
# Inserção bem-sucedida para num_seq=573
# Inserção bem-sucedida para num_seq=31
# Inserção bem-sucedida para num_seq=794
# Duplicidade encontrada para num_seq=661
# Duplicidade encontrada para num_seq=607
# Duplicidade encontrada para num_seq=190
# Inserção bem-sucedida para num_seq=681
# Duplicidade encontrada para num_seq=754
# Duplicidade encontrada para num_seq=644
# Inserção bem-sucedida para num_seq=303
# Inserção bem-sucedida para num_seq=478
# Duplicidade encontrada para num_seq=771
# Inserção bem-sucedida para num_seq=584
# Inserção bem-sucedida para num_seq=795
# Inserção bem-sucedida para num_seq=791
# Inserção bem-sucedida para num_seq=274
# Duplicidade encontrada para num_seq=656
# Inserção bem-sucedida para num_seq=562
# Duplicidade encontrada para num_seq=635
# Duplicidade encontrada para num_seq=129
# Duplicidade encontrada para num_seq=719
# Duplicidade encontrada para num_seq=195
# Duplicidade encontrada para num_seq=627
# Duplicidade encontrada para num_seq=336
# Duplicidade encontrada para num_seq=563
# Inserção bem-sucedida para num_seq=516
# Inserção bem-sucedida para num_seq=74
# Inserção bem-sucedida para num_seq=537
# Duplicidade encontrada para num_seq=403
# Inserção bem-sucedida para num_seq=470
# Inserção bem-sucedida para num_seq=189
# Inserção bem-sucedida para num_seq=150
# Inserção bem-sucedida para num_seq=5
# Inserção bem-sucedida para num_seq=475
# Inserção bem-sucedida para num_seq=582
# Inserção bem-sucedida para num_seq=331
# Inserção bem-sucedida para num_seq=574
# Inserção bem-sucedida para num_seq=345
# Duplicidade encontrada para num_seq=794
# Inserção bem-sucedida para num_seq=477
# Duplicidade encontrada para num_seq=215
# Duplicidade encontrada para num_seq=562
# Inserção bem-sucedida para num_seq=236
# Duplicidade encontrada para num_seq=144
# Duplicidade encontrada para num_seq=432
# Inserção bem-sucedida para num_seq=110
# Inserção bem-sucedida para num_seq=264
# Inserção bem-sucedida para num_seq=664
# Duplicidade encontrada para num_seq=593
# Duplicidade encontrada para num_seq=454
# Duplicidade encontrada para num_seq=302
# Inserção bem-sucedida para num_seq=633
# Duplicidade encontrada para num_seq=615
# Duplicidade encontrada para num_seq=100
# Inserção bem-sucedida para num_seq=483
# Duplicidade encontrada para num_seq=672
# Inserção bem-sucedida para num_seq=705
# Inserção bem-sucedida para num_seq=289
# Duplicidade encontrada para num_seq=282
# Inserção bem-sucedida para num_seq=160
# Inserção bem-sucedida para num_seq=293
# Duplicidade encontrada para num_seq=443
# Inserção bem-sucedida para num_seq=701
# Duplicidade encontrada para num_seq=407
# Inserção bem-sucedida para num_seq=622
# Inserção bem-sucedida para num_seq=619
# Inserção bem-sucedida para num_seq=226
# Duplicidade encontrada para num_seq=394
# Inserção bem-sucedida para num_seq=357
# Inserção bem-sucedida para num_seq=506
# Inserção bem-sucedida para num_seq=538
# Inserção bem-sucedida para num_seq=133
# Duplicidade encontrada para num_seq=546
# Inserção bem-sucedida para num_seq=745
# Inserção bem-sucedida para num_seq=476
# Duplicidade encontrada para num_seq=742
# Inserção bem-sucedida para num_seq=279
# Inserção bem-sucedida para num_seq=131
# Duplicidade encontrada para num_seq=18
# Inserção bem-sucedida para num_seq=487
# Duplicidade encontrada para num_seq=304
# Duplicidade encontrada para num_seq=500
# Inserção bem-sucedida para num_seq=28
# Duplicidade encontrada para num_seq=355
# Duplicidade encontrada para num_seq=723
# Duplicidade encontrada para num_seq=351
# Inserção bem-sucedida para num_seq=731
# Duplicidade encontrada para num_seq=150
# Inserção bem-sucedida para num_seq=75
# Duplicidade encontrada para num_seq=723
# Duplicidade encontrada para num_seq=678
# Duplicidade encontrada para num_seq=371
# Duplicidade encontrada para num_seq=289
# Inserção bem-sucedida para num_seq=764
# Duplicidade encontrada para num_seq=541
# Duplicidade encontrada para num_seq=454
# Duplicidade encontrada para num_seq=308
# Duplicidade encontrada para num_seq=346
# Duplicidade encontrada para num_seq=89
# Inserção bem-sucedida para num_seq=536
# Duplicidade encontrada para num_seq=486
# Inserção bem-sucedida para num_seq=662
# Duplicidade encontrada para num_seq=740
# Inserção bem-sucedida para num_seq=334
# Inserção bem-sucedida para num_seq=419
# Duplicidade encontrada para num_seq=239
# Inserção bem-sucedida para num_seq=608
# Inserção bem-sucedida para num_seq=445
# Inserção bem-sucedida para num_seq=462
# Duplicidade encontrada para num_seq=692
# Duplicidade encontrada para num_seq=736
# Duplicidade encontrada para num_seq=692
# Duplicidade encontrada para num_seq=728
# Inserção bem-sucedida para num_seq=64
# Inserção bem-sucedida para num_seq=81
# Inserção bem-sucedida para num_seq=281
# Inserção bem-sucedida para num_seq=775
# Duplicidade encontrada para num_seq=97
# Inserção bem-sucedida para num_seq=138
# Inserção bem-sucedida para num_seq=121
# Inserção bem-sucedida para num_seq=436
# Inserção bem-sucedida para num_seq=151
# Duplicidade encontrada para num_seq=125
# Inserção bem-sucedida para num_seq=456
# Inserção bem-sucedida para num_seq=26
# Inserção bem-sucedida para num_seq=61
# Inserção bem-sucedida para num_seq=789
# Duplicidade encontrada para num_seq=413
# Inserção bem-sucedida para num_seq=450
# Inserção bem-sucedida para num_seq=772
# Inserção bem-sucedida para num_seq=570
# Inserção bem-sucedida para num_seq=581
# Inserção bem-sucedida para num_seq=43
# Duplicidade encontrada para num_seq=50
# Inserção bem-sucedida para num_seq=374
# Inserção bem-sucedida para num_seq=199
# Duplicidade encontrada para num_seq=362
# Inserção bem-sucedida para num_seq=140
# Duplicidade encontrada para num_seq=446
# Inserção bem-sucedida para num_seq=307
# Duplicidade encontrada para num_seq=452
# Duplicidade encontrada para num_seq=108
# Inserção bem-sucedida para num_seq=729
# Duplicidade encontrada para num_seq=509
# Duplicidade encontrada para num_seq=358
# Inserção bem-sucedida para num_seq=493
# Inserção bem-sucedida para num_seq=751
# Inserção bem-sucedida para num_seq=388
# Inserção bem-sucedida para num_seq=149
# Duplicidade encontrada para num_seq=227
# Inserção bem-sucedida para num_seq=21
# Inserção bem-sucedida para num_seq=489
# Inserção bem-sucedida para num_seq=19
# Duplicidade encontrada para num_seq=599
# Inserção bem-sucedida para num_seq=716
# Duplicidade encontrada para num_seq=200
# Inserção bem-sucedida para num_seq=643
# Duplicidade encontrada para num_seq=101
# Inserção bem-sucedida para num_seq=47
# Inserção bem-sucedida para num_seq=422
# Inserção bem-sucedida para num_seq=540
# Duplicidade encontrada para num_seq=483
# Inserção bem-sucedida para num_seq=30
# Duplicidade encontrada para num_seq=316
# Duplicidade encontrada para num_seq=441
# Inserção bem-sucedida para num_seq=767
# Inserção bem-sucedida para num_seq=179
# Inserção bem-sucedida para num_seq=709
# Duplicidade encontrada para num_seq=203
# Duplicidade encontrada para num_seq=176
# Inserção bem-sucedida para num_seq=455
# Inserção bem-sucedida para num_seq=243
# Duplicidade encontrada para num_seq=34
# Duplicidade encontrada para num_seq=302
# Inserção bem-sucedida para num_seq=496
# Duplicidade encontrada para num_seq=523
# Inserção bem-sucedida para num_seq=746
# Inserção bem-sucedida para num_seq=512
# Duplicidade encontrada para num_seq=487
# Duplicidade encontrada para num_seq=26
# Inserção bem-sucedida para num_seq=63
# Inserção bem-sucedida para num_seq=272
# Duplicidade encontrada para num_seq=269
# Inserção bem-sucedida para num_seq=787
# Inserção bem-sucedida para num_seq=485
# Duplicidade encontrada para num_seq=360
# Inserção bem-sucedida para num_seq=698
# Duplicidade encontrada para num_seq=521
# Duplicidade encontrada para num_seq=155
# Duplicidade encontrada para num_seq=37
# Inserção bem-sucedida para num_seq=734
# Duplicidade encontrada para num_seq=260
# Duplicidade encontrada para num_seq=516
# Inserção bem-sucedida para num_seq=800
# Inserção bem-sucedida para num_seq=349
# Inserção bem-sucedida para num_seq=690
# Duplicidade encontrada para num_seq=559
# Duplicidade encontrada para num_seq=382
# Inserção bem-sucedida para num_seq=739
# Inserção bem-sucedida para num_seq=752
# Duplicidade encontrada para num_seq=766
# Inserção bem-sucedida para num_seq=636
# Duplicidade encontrada para num_seq=716
# Duplicidade encontrada para num_seq=63
# Inserção bem-sucedida para num_seq=679
# Inserção bem-sucedida para num_seq=720
# Duplicidade encontrada para num_seq=722
# Inserção bem-sucedida para num_seq=94
# Duplicidade encontrada para num_seq=753
# Inserção bem-sucedida para num_seq=410
# Duplicidade encontrada para num_seq=268
# Inserção bem-sucedida para num_seq=669
# Duplicidade encontrada para num_seq=337
# Inserção bem-sucedida para num_seq=145
# Inserção bem-sucedida para num_seq=724
# Inserção bem-sucedida para num_seq=385
# Inserção bem-sucedida para num_seq=467
# Duplicidade encontrada para num_seq=345
# Inserção bem-sucedida para num_seq=366
# Duplicidade encontrada para num_seq=316
# Inserção bem-sucedida para num_seq=428
# Duplicidade encontrada para num_seq=535
# Duplicidade encontrada para num_seq=203
# Inserção bem-sucedida para num_seq=686
# Duplicidade encontrada para num_seq=540
# Inserção bem-sucedida para num_seq=725
# Duplicidade encontrada para num_seq=441
# Duplicidade encontrada para num_seq=257
# Duplicidade encontrada para num_seq=33
# Duplicidade encontrada para num_seq=635
# Duplicidade encontrada para num_seq=236
# Duplicidade encontrada para num_seq=541
# Inserção bem-sucedida para num_seq=711
# Duplicidade encontrada para num_seq=478
# Duplicidade encontrada para num_seq=307
# Inserção bem-sucedida para num_seq=29
# Duplicidade encontrada para num_seq=669
# Inserção bem-sucedida para num_seq=67
# Inserção bem-sucedida para num_seq=553
# Inserção bem-sucedida para num_seq=469
# Inserção bem-sucedida para num_seq=649
# Duplicidade encontrada para num_seq=390
# Inserção bem-sucedida para num_seq=156
# Inserção bem-sucedida para num_seq=696
# Duplicidade encontrada para num_seq=243
# Inserção bem-sucedida para num_seq=431
# Inserção bem-sucedida para num_seq=141
# Inserção bem-sucedida para num_seq=566
# Duplicidade encontrada para num_seq=10
# Duplicidade encontrada para num_seq=718
# Inserção bem-sucedida para num_seq=342
# Inserção bem-sucedida para num_seq=618
# Duplicidade encontrada para num_seq=512
# Duplicidade encontrada para num_seq=360
# Duplicidade encontrada para num_seq=593
# Inserção bem-sucedida para num_seq=216
# Inserção bem-sucedida para num_seq=53
# Duplicidade encontrada para num_seq=573
# Duplicidade encontrada para num_seq=226
# Inserção bem-sucedida para num_seq=641
# Inserção bem-sucedida para num_seq=364
# Inserção bem-sucedida para num_seq=702
# Duplicidade encontrada para num_seq=729
# Duplicidade encontrada para num_seq=137
# Inserção bem-sucedida para num_seq=447
# Inserção bem-sucedida para num_seq=230
# Duplicidade encontrada para num_seq=413
# Duplicidade encontrada para num_seq=121
# Inserção bem-sucedida para num_seq=213
# Inserção bem-sucedida para num_seq=276
# Inserção bem-sucedida para num_seq=372
# Duplicidade encontrada para num_seq=67
# Inserção bem-sucedida para num_seq=306
# Inserção bem-sucedida para num_seq=192
# Duplicidade encontrada para num_seq=301
# Duplicidade encontrada para num_seq=289
# Duplicidade encontrada para num_seq=546
# Inserção bem-sucedida para num_seq=714
# Inserção bem-sucedida para num_seq=23
# Duplicidade encontrada para num_seq=456
# Inserção bem-sucedida para num_seq=693
# Inserção bem-sucedida para num_seq=365
# Duplicidade encontrada para num_seq=664
# Inserção bem-sucedida para num_seq=48
# Duplicidade encontrada para num_seq=668
# Duplicidade encontrada para num_seq=750
# Duplicidade encontrada para num_seq=680
# Inserção bem-sucedida para num_seq=801
# Inserção bem-sucedida para num_seq=603
# Duplicidade encontrada para num_seq=671
# Inserção bem-sucedida para num_seq=69
# Inserção bem-sucedida para num_seq=185
# Duplicidade encontrada para num_seq=562
# Duplicidade encontrada para num_seq=497
# Duplicidade encontrada para num_seq=216
# Inserção bem-sucedida para num_seq=481
# Inserção bem-sucedida para num_seq=624
# Duplicidade encontrada para num_seq=513
# Duplicidade encontrada para num_seq=546
# Inserção bem-sucedida para num_seq=442
# Inserção bem-sucedida para num_seq=292
# Inserção bem-sucedida para num_seq=610
# Duplicidade encontrada para num_seq=469
# Duplicidade encontrada para num_seq=149
# Duplicidade encontrada para num_seq=292
# Duplicidade encontrada para num_seq=469
# Inserção bem-sucedida para num_seq=529
# Duplicidade encontrada para num_seq=719
# Duplicidade encontrada para num_seq=336
# Inserção bem-sucedida para num_seq=741
# Inserção bem-sucedida para num_seq=640
# Inserção bem-sucedida para num_seq=229
# Inserção bem-sucedida para num_seq=66
# Inserção bem-sucedida para num_seq=585
# Duplicidade encontrada para num_seq=108
# Duplicidade encontrada para num_seq=727
# Inserção bem-sucedida para num_seq=612
# Inserção bem-sucedida para num_seq=495
# Inserção bem-sucedida para num_seq=233
# Duplicidade encontrada para num_seq=572
# Duplicidade encontrada para num_seq=614
# Duplicidade encontrada para num_seq=436
# Duplicidade encontrada para num_seq=803
# Inserção bem-sucedida para num_seq=567
# Duplicidade encontrada para num_seq=125
# Duplicidade encontrada para num_seq=510
# Duplicidade encontrada para num_seq=546
# Duplicidade encontrada para num_seq=19
# Duplicidade encontrada para num_seq=509
# Duplicidade encontrada para num_seq=506
# Inserção bem-sucedida para num_seq=39
# Inserção bem-sucedida para num_seq=380
# Duplicidade encontrada para num_seq=215
# Inserção bem-sucedida para num_seq=479
# Duplicidade encontrada para num_seq=239
# Duplicidade encontrada para num_seq=490
# Duplicidade encontrada para num_seq=19
# Inserção bem-sucedida para num_seq=544
# Duplicidade encontrada para num_seq=52
# Inserção bem-sucedida para num_seq=152
# Inserção bem-sucedida para num_seq=252
# Inserção bem-sucedida para num_seq=338
# Duplicidade encontrada para num_seq=373
# Duplicidade encontrada para num_seq=113
# Duplicidade encontrada para num_seq=233
# Duplicidade encontrada para num_seq=179
# Duplicidade encontrada para num_seq=703
# Duplicidade encontrada para num_seq=289
# Inserção bem-sucedida para num_seq=312
# Duplicidade encontrada para num_seq=176
# Inserção bem-sucedida para num_seq=587
# Duplicidade encontrada para num_seq=721
# Inserção bem-sucedida para num_seq=596
# Inserção bem-sucedida para num_seq=80
# Duplicidade encontrada para num_seq=582
# Duplicidade encontrada para num_seq=69
# Inserção bem-sucedida para num_seq=528
# Inserção bem-sucedida para num_seq=341
# Duplicidade encontrada para num_seq=791
# Inserção bem-sucedida para num_seq=62
# Inserção bem-sucedida para num_seq=72
# Inserção bem-sucedida para num_seq=130
# Inserção bem-sucedida para num_seq=503
# Duplicidade encontrada para num_seq=692
# Duplicidade encontrada para num_seq=72
# Duplicidade encontrada para num_seq=517
# Duplicidade encontrada para num_seq=714
# Duplicidade encontrada para num_seq=413
# Duplicidade encontrada para num_seq=84
# Duplicidade encontrada para num_seq=659
# Duplicidade encontrada para num_seq=254
# Inserção bem-sucedida para num_seq=430
# Duplicidade encontrada para num_seq=189
# Inserção bem-sucedida para num_seq=169
# Inserção bem-sucedida para num_seq=57
# Inserção bem-sucedida para num_seq=116
# Duplicidade encontrada para num_seq=422
# Duplicidade encontrada para num_seq=141
# Duplicidade encontrada para num_seq=481
# Duplicidade encontrada para num_seq=337
# Duplicidade encontrada para num_seq=558
# Duplicidade encontrada para num_seq=55
# Inserção bem-sucedida para num_seq=223
# Inserção bem-sucedida para num_seq=543
# Inserção bem-sucedida para num_seq=564
# Inserção bem-sucedida para num_seq=677
# Inserção bem-sucedida para num_seq=283
# Inserção bem-sucedida para num_seq=320
# Duplicidade encontrada para num_seq=189
# Inserção bem-sucedida para num_seq=460
# Duplicidade encontrada para num_seq=780
# Inserção bem-sucedida para num_seq=250
# Duplicidade encontrada para num_seq=803
# Duplicidade encontrada para num_seq=394
# Inserção bem-sucedida para num_seq=73
# Duplicidade encontrada para num_seq=148
# Duplicidade encontrada para num_seq=179
# Duplicidade encontrada para num_seq=223
# Duplicidade encontrada para num_seq=148
# Inserção bem-sucedida para num_seq=383
# Inserção bem-sucedida para num_seq=759
# Duplicidade encontrada para num_seq=497
# Duplicidade encontrada para num_seq=165
# Inserção bem-sucedida para num_seq=25
# Inserção bem-sucedida para num_seq=326
# Duplicidade encontrada para num_seq=469
# Inserção bem-sucedida para num_seq=697
# Inserção bem-sucedida para num_seq=579
# Inserção bem-sucedida para num_seq=319
# Duplicidade encontrada para num_seq=5
# Inserção bem-sucedida para num_seq=142
# Inserção bem-sucedida para num_seq=411
# Inserção bem-sucedida para num_seq=488
# Duplicidade encontrada para num_seq=652
# Duplicidade encontrada para num_seq=583
# Duplicidade encontrada para num_seq=720
# Inserção bem-sucedida para num_seq=592
# Inserção bem-sucedida para num_seq=191
# Duplicidade encontrada para num_seq=615
# Inserção bem-sucedida para num_seq=78
# Inserção bem-sucedida para num_seq=606
# Inserção bem-sucedida para num_seq=522
# Duplicidade encontrada para num_seq=108
# Inserção bem-sucedida para num_seq=416
# Duplicidade encontrada para num_seq=801
# Inserção bem-sucedida para num_seq=424
# Inserção bem-sucedida para num_seq=286
# Duplicidade encontrada para num_seq=702
# Inserção bem-sucedida para num_seq=501
# Duplicidade encontrada para num_seq=39
# Duplicidade encontrada para num_seq=521
# Inserção bem-sucedida para num_seq=665
# Duplicidade encontrada para num_seq=634
# Inserção bem-sucedida para num_seq=44
# Duplicidade encontrada para num_seq=164
# Inserção bem-sucedida para num_seq=453
# Duplicidade encontrada para num_seq=486
# Duplicidade encontrada para num_seq=152
# Duplicidade encontrada para num_seq=486
# Inserção bem-sucedida para num_seq=707
# Duplicidade encontrada para num_seq=641
# Duplicidade encontrada para num_seq=486
# Duplicidade encontrada para num_seq=798
# Duplicidade encontrada para num_seq=784
# Duplicidade encontrada para num_seq=571
# Duplicidade encontrada para num_seq=169
# Inserção bem-sucedida para num_seq=533
# Duplicidade encontrada para num_seq=79
# Duplicidade encontrada para num_seq=69
# Inserção bem-sucedida para num_seq=663
# Duplicidade encontrada para num_seq=359

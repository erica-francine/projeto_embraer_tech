# %%
from random import randint, choice
import mysql.connector

# %%
conexao = mysql.connector.connect(
    host='localhost',
    user='root',
    password='admin',
    database='custos_transporte'
)

# %%
cursor = conexao.cursor()

# Pegando todos os id_compra_materia_prima do MySQL da tabela compra_materia_prima e armazenando em uma variável
cursor.execute("SELECT id_compra FROM compra_materia_prima")
compra_materia_prima = cursor.fetchall()

# Pegando todos os cod_materia_prima do MySQL da tabela materia_prima e armazenando em uma variável
cursor.execute("SELECT cod_materia_prima FROM materia_prima")
materia_prima = cursor.fetchall()

# Pegando todos os id_modelo do MySQL da tabela modelo_aviao e armazenando em uma variável
cursor.execute("SELECT id_aviao FROM producao_aviao")
producao_aviao = cursor.fetchall()

# %%
cursor = conexao.cursor()

# Função que vai gerar 800 registros aleatórios e inserir no MySQL na tabela item_compra
def item_compra():
    nums_seq_existentes = set()
      
    for _ in range(800):
        num_seq = randint(0, 800)
        
        while num_seq in nums_seq_existentes:
            num_seq = randint(0, 800)

            nums_seq_existentes.add(num_seq)
            
            print(f"Tentando inserir num_seq={num_seq}")
            
        quantidade = randint(5, 50)

        # Pegando IDs aleatórios das tabelas
        compra_materia_prima_id_compra = choice(compra_materia_prima)[0]
        materia_prima_cod_materia_prima = choice(materia_prima)[0]
        producao_aviao_id_aviao = choice(producao_aviao)[0]

        # Pegando IDs das tabelas compra_materia_prima, materia_prima e producao_aviao
        cursor.execute("SELECT id_compra FROM compra_materia_prima WHERE id_compra = %s", (compra_materia_prima_id_compra,))
        compra_materia_prima_id_compra = cursor.fetchone()[0]

        cursor.execute("SELECT cod_materia_prima FROM materia_prima WHERE cod_materia_prima = %s", (materia_prima_cod_materia_prima,))
        materia_prima_cod_materia_prima = cursor.fetchone()[0]

        cursor.execute("SELECT id_aviao FROM producao_aviao WHERE id_aviao = %s", (producao_aviao_id_aviao,))
        producao_aviao_id_aviao = cursor.fetchone()[0]

        # Inserindo dados na tabela
        try:
            insert_query = "INSERT INTO item_compra (num_seq, compra_materia_prima_id_compra, materia_prima_cod_materia_prima, quantidade, producao_aviao_id_aviao) VALUES (%s, %s, %s, %s, %s);"
            data = (num_seq, compra_materia_prima_id_compra, materia_prima_cod_materia_prima, quantidade, producao_aviao_id_aviao)
            cursor.execute(insert_query, data)
        
            conexao.commit()
    
            print(f"Inserção bem-sucedida para num_seq={num_seq}")
        except mysql.connector.Error as err:
            if err.errno == mysql.connector.errorcode.ER_DUP_ENTRY:
                print(f"Duplicidade encontrada para num_seq={num_seq}")
            else:
                print(f"Erro ao inserir: {err}")

# Chamando a função para gerar os registros
item_compra()

# Fechando a conexão
cursor.close()
conexao.close()
# Out:
# Inserção bem-sucedida para num_seq=647
# Duplicidade encontrada para num_seq=156
# Duplicidade encontrada para num_seq=559
# Duplicidade encontrada para num_seq=745
# Duplicidade encontrada para num_seq=184
# Duplicidade encontrada para num_seq=135
# Inserção bem-sucedida para num_seq=54
# Duplicidade encontrada para num_seq=194
# Duplicidade encontrada para num_seq=695
# Inserção bem-sucedida para num_seq=171
# Duplicidade encontrada para num_seq=501
# Inserção bem-sucedida para num_seq=263
# Inserção bem-sucedida para num_seq=675
# Duplicidade encontrada para num_seq=169
# Duplicidade encontrada para num_seq=113
# Inserção bem-sucedida para num_seq=111
# Inserção bem-sucedida para num_seq=49
# Inserção bem-sucedida para num_seq=231
# Duplicidade encontrada para num_seq=482
# Inserção bem-sucedida para num_seq=99
# Duplicidade encontrada para num_seq=357
# Duplicidade encontrada para num_seq=286
# Duplicidade encontrada para num_seq=688
# Duplicidade encontrada para num_seq=287
# Duplicidade encontrada para num_seq=606
# Duplicidade encontrada para num_seq=328
# Duplicidade encontrada para num_seq=191
# Duplicidade encontrada para num_seq=301
# Duplicidade encontrada para num_seq=470
# Duplicidade encontrada para num_seq=256
# Duplicidade encontrada para num_seq=93
# Inserção bem-sucedida para num_seq=699
# Duplicidade encontrada para num_seq=740
# Duplicidade encontrada para num_seq=355
# Duplicidade encontrada para num_seq=701
# Inserção bem-sucedida para num_seq=253
# Duplicidade encontrada para num_seq=230
# Inserção bem-sucedida para num_seq=369
# Duplicidade encontrada para num_seq=624
# Duplicidade encontrada para num_seq=431
# Duplicidade encontrada para num_seq=535
# Duplicidade encontrada para num_seq=746
# Duplicidade encontrada para num_seq=215
# Duplicidade encontrada para num_seq=325
# Duplicidade encontrada para num_seq=513
# Inserção bem-sucedida para num_seq=102
# Duplicidade encontrada para num_seq=58
# Inserção bem-sucedida para num_seq=153
# Duplicidade encontrada para num_seq=28
# Duplicidade encontrada para num_seq=594
# Duplicidade encontrada para num_seq=680
# Duplicidade encontrada para num_seq=546
# Inserção bem-sucedida para num_seq=245
# Duplicidade encontrada para num_seq=10
# Duplicidade encontrada para num_seq=767
# Inserção bem-sucedida para num_seq=12
# Inserção bem-sucedida para num_seq=277
# Duplicidade encontrada para num_seq=127
# Inserção bem-sucedida para num_seq=202
# Duplicidade encontrada para num_seq=581
# Inserção bem-sucedida para num_seq=401
# Duplicidade encontrada para num_seq=133
# Duplicidade encontrada para num_seq=322
# Duplicidade encontrada para num_seq=73
# Duplicidade encontrada para num_seq=136
# Duplicidade encontrada para num_seq=735
# Duplicidade encontrada para num_seq=754
# Duplicidade encontrada para num_seq=144
# Inserção bem-sucedida para num_seq=505
# Duplicidade encontrada para num_seq=370
# Inserção bem-sucedida para num_seq=238
# Duplicidade encontrada para num_seq=283
# Inserção bem-sucedida para num_seq=333
# Inserção bem-sucedida para num_seq=32
# Duplicidade encontrada para num_seq=378
# Duplicidade encontrada para num_seq=767
# Duplicidade encontrada para num_seq=604
# Inserção bem-sucedida para num_seq=629
# Duplicidade encontrada para num_seq=475
# Duplicidade encontrada para num_seq=195
# Inserção bem-sucedida para num_seq=70
# Duplicidade encontrada para num_seq=137
# Inserção bem-sucedida para num_seq=217
# Inserção bem-sucedida para num_seq=626
# Duplicidade encontrada para num_seq=744
# Inserção bem-sucedida para num_seq=82
# Inserção bem-sucedida para num_seq=427
# Duplicidade encontrada para num_seq=214
# Duplicidade encontrada para num_seq=191
# Inserção bem-sucedida para num_seq=628
# Inserção bem-sucedida para num_seq=166
# Inserção bem-sucedida para num_seq=639
# Duplicidade encontrada para num_seq=362
# Duplicidade encontrada para num_seq=754
# Duplicidade encontrada para num_seq=587
# Inserção bem-sucedida para num_seq=406
# Duplicidade encontrada para num_seq=305
# Duplicidade encontrada para num_seq=528
# Duplicidade encontrada para num_seq=330
# Duplicidade encontrada para num_seq=337
# Duplicidade encontrada para num_seq=418
# Duplicidade encontrada para num_seq=230
# Duplicidade encontrada para num_seq=724
# Inserção bem-sucedida para num_seq=425
# Duplicidade encontrada para num_seq=791
# Inserção bem-sucedida para num_seq=498
# Duplicidade encontrada para num_seq=755
# Duplicidade encontrada para num_seq=559
# Inserção bem-sucedida para num_seq=211
# Duplicidade encontrada para num_seq=483
# Duplicidade encontrada para num_seq=281
# Inserção bem-sucedida para num_seq=730
# Duplicidade encontrada para num_seq=15
# Inserção bem-sucedida para num_seq=399
# Inserção bem-sucedida para num_seq=246
# Duplicidade encontrada para num_seq=192
# Inserção bem-sucedida para num_seq=783
# Inserção bem-sucedida para num_seq=381
# Inserção bem-sucedida para num_seq=290
# Duplicidade encontrada para num_seq=554
# Inserção bem-sucedida para num_seq=480
# Duplicidade encontrada para num_seq=671
# Duplicidade encontrada para num_seq=470
# Inserção bem-sucedida para num_seq=235
# Duplicidade encontrada para num_seq=428
# Duplicidade encontrada para num_seq=43
# Duplicidade encontrada para num_seq=566
# Inserção bem-sucedida para num_seq=3
# Duplicidade encontrada para num_seq=540
# Duplicidade encontrada para num_seq=232
# Duplicidade encontrada para num_seq=590
# Duplicidade encontrada para num_seq=722
# Duplicidade encontrada para num_seq=6
# Duplicidade encontrada para num_seq=746
# Duplicidade encontrada para num_seq=508
# Duplicidade encontrada para num_seq=279
# Duplicidade encontrada para num_seq=761
# Duplicidade encontrada para num_seq=634
# Inserção bem-sucedida para num_seq=210
# Inserção bem-sucedida para num_seq=161
# Duplicidade encontrada para num_seq=490
# Inserção bem-sucedida para num_seq=433
# Inserção bem-sucedida para num_seq=588
# Inserção bem-sucedida para num_seq=637
# Duplicidade encontrada para num_seq=442
# Inserção bem-sucedida para num_seq=375
# Inserção bem-sucedida para num_seq=139
# Duplicidade encontrada para num_seq=14
# Duplicidade encontrada para num_seq=217
# Inserção bem-sucedida para num_seq=16
# Inserção bem-sucedida para num_seq=429
# Duplicidade encontrada para num_seq=525
# Duplicidade encontrada para num_seq=776
# Duplicidade encontrada para num_seq=652
# Duplicidade encontrada para num_seq=125
# Duplicidade encontrada para num_seq=23
# Duplicidade encontrada para num_seq=665
# Duplicidade encontrada para num_seq=742
# Duplicidade encontrada para num_seq=455
# Inserção bem-sucedida para num_seq=797
# Inserção bem-sucedida para num_seq=134
# Duplicidade encontrada para num_seq=685
# Duplicidade encontrada para num_seq=420
# Duplicidade encontrada para num_seq=148
# Duplicidade encontrada para num_seq=731
# Duplicidade encontrada para num_seq=148
# Duplicidade encontrada para num_seq=696
# Duplicidade encontrada para num_seq=641
# Duplicidade encontrada para num_seq=279
# Duplicidade encontrada para num_seq=11
# Duplicidade encontrada para num_seq=252
# Duplicidade encontrada para num_seq=422
# Duplicidade encontrada para num_seq=444
# Inserção bem-sucedida para num_seq=437
# Duplicidade encontrada para num_seq=422
# Duplicidade encontrada para num_seq=538
# Duplicidade encontrada para num_seq=717
# Inserção bem-sucedida para num_seq=68
# Duplicidade encontrada para num_seq=667
# Duplicidade encontrada para num_seq=3
# Duplicidade encontrada para num_seq=312
# Inserção bem-sucedida para num_seq=461
# Duplicidade encontrada para num_seq=656
# Duplicidade encontrada para num_seq=634
# Duplicidade encontrada para num_seq=686
# Duplicidade encontrada para num_seq=323
# Duplicidade encontrada para num_seq=736
# Duplicidade encontrada para num_seq=436
# Duplicidade encontrada para num_seq=553
# Duplicidade encontrada para num_seq=333
# Inserção bem-sucedida para num_seq=415
# Inserção bem-sucedida para num_seq=646
# Duplicidade encontrada para num_seq=475
# Inserção bem-sucedida para num_seq=212
# Inserção bem-sucedida para num_seq=507
# Duplicidade encontrada para num_seq=776
# Duplicidade encontrada para num_seq=512
# Duplicidade encontrada para num_seq=281
# Duplicidade encontrada para num_seq=769
# Inserção bem-sucedida para num_seq=177
# Duplicidade encontrada para num_seq=250
# Duplicidade encontrada para num_seq=741
# Duplicidade encontrada para num_seq=717
# Inserção bem-sucedida para num_seq=451
# Inserção bem-sucedida para num_seq=123
# Duplicidade encontrada para num_seq=703
# Inserção bem-sucedida para num_seq=704
# Inserção bem-sucedida para num_seq=103
# Duplicidade encontrada para num_seq=149
# Duplicidade encontrada para num_seq=444
# Duplicidade encontrada para num_seq=783
# Duplicidade encontrada para num_seq=262
# Duplicidade encontrada para num_seq=486
# Duplicidade encontrada para num_seq=632
# Duplicidade encontrada para num_seq=15
# Inserção bem-sucedida para num_seq=193
# Inserção bem-sucedida para num_seq=41
# Duplicidade encontrada para num_seq=16
# Duplicidade encontrada para num_seq=702
# Duplicidade encontrada para num_seq=593
# Duplicidade encontrada para num_seq=512
# Duplicidade encontrada para num_seq=337
# Inserção bem-sucedida para num_seq=653
# Inserção bem-sucedida para num_seq=278
# Duplicidade encontrada para num_seq=696
# Duplicidade encontrada para num_seq=588
# Duplicidade encontrada para num_seq=80
# Duplicidade encontrada para num_seq=429
# Duplicidade encontrada para num_seq=289
# Duplicidade encontrada para num_seq=680
# Inserção bem-sucedida para num_seq=499
# Duplicidade encontrada para num_seq=479
# Duplicidade encontrada para num_seq=61
# Duplicidade encontrada para num_seq=673
# Duplicidade encontrada para num_seq=302
# Inserção bem-sucedida para num_seq=577
# Duplicidade encontrada para num_seq=167
# Inserção bem-sucedida para num_seq=600
# Duplicidade encontrada para num_seq=636
# Inserção bem-sucedida para num_seq=296
# Duplicidade encontrada para num_seq=398
# Inserção bem-sucedida para num_seq=17
# Duplicidade encontrada para num_seq=723
# Duplicidade encontrada para num_seq=263
# Inserção bem-sucedida para num_seq=317
# Inserção bem-sucedida para num_seq=457
# Inserção bem-sucedida para num_seq=793
# Duplicidade encontrada para num_seq=746
# Duplicidade encontrada para num_seq=233
# Duplicidade encontrada para num_seq=503
# Duplicidade encontrada para num_seq=610
# Duplicidade encontrada para num_seq=254
# Duplicidade encontrada para num_seq=481
# Duplicidade encontrada para num_seq=12
# Duplicidade encontrada para num_seq=736
# Duplicidade encontrada para num_seq=653
# Duplicidade encontrada para num_seq=592
# Inserção bem-sucedida para num_seq=549
# Duplicidade encontrada para num_seq=166
# Duplicidade encontrada para num_seq=407
# Duplicidade encontrada para num_seq=365
# Duplicidade encontrada para num_seq=83
# Duplicidade encontrada para num_seq=607
# Duplicidade encontrada para num_seq=497
# Inserção bem-sucedida para num_seq=120
# Duplicidade encontrada para num_seq=242
# Duplicidade encontrada para num_seq=341
# Duplicidade encontrada para num_seq=537
# Duplicidade encontrada para num_seq=679
# Inserção bem-sucedida para num_seq=261
# Inserção bem-sucedida para num_seq=532
# Duplicidade encontrada para num_seq=593
# Duplicidade encontrada para num_seq=595
# Duplicidade encontrada para num_seq=32
# Duplicidade encontrada para num_seq=213
# Inserção bem-sucedida para num_seq=309
# Duplicidade encontrada para num_seq=215
# Duplicidade encontrada para num_seq=373
# Duplicidade encontrada para num_seq=419
# Duplicidade encontrada para num_seq=160
# Duplicidade encontrada para num_seq=362
# Inserção bem-sucedida para num_seq=598
# Duplicidade encontrada para num_seq=212
# Inserção bem-sucedida para num_seq=168
# Duplicidade encontrada para num_seq=400
# Inserção bem-sucedida para num_seq=204
# Duplicidade encontrada para num_seq=797
# Duplicidade encontrada para num_seq=16
# Duplicidade encontrada para num_seq=194
# Duplicidade encontrada para num_seq=389
# Duplicidade encontrada para num_seq=449
# Duplicidade encontrada para num_seq=768
# Duplicidade encontrada para num_seq=6
# Inserção bem-sucedida para num_seq=613
# Duplicidade encontrada para num_seq=290
# Inserção bem-sucedida para num_seq=561
# Duplicidade encontrada para num_seq=422
# Inserção bem-sucedida para num_seq=778
# Duplicidade encontrada para num_seq=166
# Duplicidade encontrada para num_seq=696
# Inserção bem-sucedida para num_seq=294
# Inserção bem-sucedida para num_seq=318
# Duplicidade encontrada para num_seq=497
# Duplicidade encontrada para num_seq=471
# Duplicidade encontrada para num_seq=213
# Inserção bem-sucedida para num_seq=670
# Duplicidade encontrada para num_seq=233
# Duplicidade encontrada para num_seq=145
# Inserção bem-sucedida para num_seq=651
# Duplicidade encontrada para num_seq=546
# Duplicidade encontrada para num_seq=227
# Duplicidade encontrada para num_seq=103
# Duplicidade encontrada para num_seq=784
# Duplicidade encontrada para num_seq=290
# Duplicidade encontrada para num_seq=494
# Inserção bem-sucedida para num_seq=244
# Inserção bem-sucedida para num_seq=354
# Inserção bem-sucedida para num_seq=280
# Duplicidade encontrada para num_seq=189
# Duplicidade encontrada para num_seq=560
# Duplicidade encontrada para num_seq=470
# Duplicidade encontrada para num_seq=389
# Duplicidade encontrada para num_seq=774
# Inserção bem-sucedida para num_seq=46
# Duplicidade encontrada para num_seq=660
# Inserção bem-sucedida para num_seq=464
# Inserção bem-sucedida para num_seq=491
# Duplicidade encontrada para num_seq=101
# Inserção bem-sucedida para num_seq=332
# Duplicidade encontrada para num_seq=606
# Duplicidade encontrada para num_seq=764
# Duplicidade encontrada para num_seq=512
# Duplicidade encontrada para num_seq=562
# Duplicidade encontrada para num_seq=11
# Duplicidade encontrada para num_seq=489
# Duplicidade encontrada para num_seq=6
# Duplicidade encontrada para num_seq=380
# Duplicidade encontrada para num_seq=794
# Duplicidade encontrada para num_seq=392
# Duplicidade encontrada para num_seq=624
# Inserção bem-sucedida para num_seq=395
# Inserção bem-sucedida para num_seq=788
# Duplicidade encontrada para num_seq=599
# Duplicidade encontrada para num_seq=656
# Duplicidade encontrada para num_seq=346
# Duplicidade encontrada para num_seq=516
# Duplicidade encontrada para num_seq=605
# Duplicidade encontrada para num_seq=672
# Duplicidade encontrada para num_seq=280
# Duplicidade encontrada para num_seq=73
# Inserção bem-sucedida para num_seq=423
# Duplicidade encontrada para num_seq=363
# Duplicidade encontrada para num_seq=449
# Duplicidade encontrada para num_seq=657
# Duplicidade encontrada para num_seq=215
# Inserção bem-sucedida para num_seq=367
# Duplicidade encontrada para num_seq=388
# Duplicidade encontrada para num_seq=583
# Inserção bem-sucedida para num_seq=555
# Duplicidade encontrada para num_seq=290
# Duplicidade encontrada para num_seq=27
# Duplicidade encontrada para num_seq=407
# Duplicidade encontrada para num_seq=537
# Inserção bem-sucedida para num_seq=267
# Duplicidade encontrada para num_seq=376
# Inserção bem-sucedida para num_seq=248
# Inserção bem-sucedida para num_seq=208
# Duplicidade encontrada para num_seq=553
# Duplicidade encontrada para num_seq=420
# Duplicidade encontrada para num_seq=363
# Duplicidade encontrada para num_seq=476
# Inserção bem-sucedida para num_seq=708
# Inserção bem-sucedida para num_seq=519
# Duplicidade encontrada para num_seq=552
# Duplicidade encontrada para num_seq=46
# Duplicidade encontrada para num_seq=236
# Duplicidade encontrada para num_seq=182
# Inserção bem-sucedida para num_seq=104
# Duplicidade encontrada para num_seq=724
# Duplicidade encontrada para num_seq=456
# Duplicidade encontrada para num_seq=488
# Duplicidade encontrada para num_seq=540
# Duplicidade encontrada para num_seq=276
# Inserção bem-sucedida para num_seq=206
# Duplicidade encontrada para num_seq=205
# Inserção bem-sucedida para num_seq=0
# Inserção bem-sucedida para num_seq=77
# Duplicidade encontrada para num_seq=265
# Duplicidade encontrada para num_seq=246
# Duplicidade encontrada para num_seq=364
# Duplicidade encontrada para num_seq=604
# Duplicidade encontrada para num_seq=232
# Duplicidade encontrada para num_seq=169
# Duplicidade encontrada para num_seq=11
# Duplicidade encontrada para num_seq=732
# Duplicidade encontrada para num_seq=310
# Duplicidade encontrada para num_seq=501
# Duplicidade encontrada para num_seq=685
# Duplicidade encontrada para num_seq=70
# Duplicidade encontrada para num_seq=275
# Duplicidade encontrada para num_seq=778
# Duplicidade encontrada para num_seq=595
# Duplicidade encontrada para num_seq=698
# Inserção bem-sucedida para num_seq=757
# Duplicidade encontrada para num_seq=496
# Duplicidade encontrada para num_seq=216
# Duplicidade encontrada para num_seq=290
# Duplicidade encontrada para num_seq=580
# Inserção bem-sucedida para num_seq=273
# Inserção bem-sucedida para num_seq=270
# Duplicidade encontrada para num_seq=449
# Duplicidade encontrada para num_seq=239
# Duplicidade encontrada para num_seq=357
# Duplicidade encontrada para num_seq=32
# Inserção bem-sucedida para num_seq=249
# Duplicidade encontrada para num_seq=130
# Duplicidade encontrada para num_seq=126
# Duplicidade encontrada para num_seq=23
# Duplicidade encontrada para num_seq=326
# Duplicidade encontrada para num_seq=19
# Inserção bem-sucedida para num_seq=575
# Duplicidade encontrada para num_seq=445
# Duplicidade encontrada para num_seq=784
# Duplicidade encontrada para num_seq=248
# Duplicidade encontrada para num_seq=736
# Duplicidade encontrada para num_seq=774
# Duplicidade encontrada para num_seq=728
# Duplicidade encontrada para num_seq=242
# Inserção bem-sucedida para num_seq=85
# Duplicidade encontrada para num_seq=43
# Duplicidade encontrada para num_seq=705
# Duplicidade encontrada para num_seq=419
# Duplicidade encontrada para num_seq=149
# Duplicidade encontrada para num_seq=423
# Duplicidade encontrada para num_seq=636
# Duplicidade encontrada para num_seq=424
# Duplicidade encontrada para num_seq=268
# Duplicidade encontrada para num_seq=289
# Duplicidade encontrada para num_seq=232
# Duplicidade encontrada para num_seq=10
# Duplicidade encontrada para num_seq=596
# Duplicidade encontrada para num_seq=632
# Duplicidade encontrada para num_seq=640
# Duplicidade encontrada para num_seq=354
# Duplicidade encontrada para num_seq=546
# Duplicidade encontrada para num_seq=577
# Duplicidade encontrada para num_seq=177
# Duplicidade encontrada para num_seq=158
# Duplicidade encontrada para num_seq=495
# Duplicidade encontrada para num_seq=131
# Duplicidade encontrada para num_seq=496
# Duplicidade encontrada para num_seq=310
# Duplicidade encontrada para num_seq=134
# Duplicidade encontrada para num_seq=718
# Duplicidade encontrada para num_seq=432
# Duplicidade encontrada para num_seq=329
# Duplicidade encontrada para num_seq=671
# Duplicidade encontrada para num_seq=267
# Duplicidade encontrada para num_seq=85
# Duplicidade encontrada para num_seq=495
# Inserção bem-sucedida para num_seq=515
# Duplicidade encontrada para num_seq=679
# Duplicidade encontrada para num_seq=305
# Duplicidade encontrada para num_seq=211
# Duplicidade encontrada para num_seq=545
# Duplicidade encontrada para num_seq=204
# Duplicidade encontrada para num_seq=199
# Duplicidade encontrada para num_seq=199
# Duplicidade encontrada para num_seq=153
# Duplicidade encontrada para num_seq=783
# Inserção bem-sucedida para num_seq=773
# Duplicidade encontrada para num_seq=445
# Duplicidade encontrada para num_seq=185
# Duplicidade encontrada para num_seq=705
# Duplicidade encontrada para num_seq=374
# Duplicidade encontrada para num_seq=731
# Duplicidade encontrada para num_seq=226
# Duplicidade encontrada para num_seq=149
# Inserção bem-sucedida para num_seq=408
# Duplicidade encontrada para num_seq=495
# Duplicidade encontrada para num_seq=585
# Duplicidade encontrada para num_seq=545
# Duplicidade encontrada para num_seq=632
# Inserção bem-sucedida para num_seq=393
# Duplicidade encontrada para num_seq=62
# Duplicidade encontrada para num_seq=289
# Duplicidade encontrada para num_seq=561
# Duplicidade encontrada para num_seq=645
# Duplicidade encontrada para num_seq=525
# Duplicidade encontrada para num_seq=212
# Duplicidade encontrada para num_seq=745
# Duplicidade encontrada para num_seq=780
# Duplicidade encontrada para num_seq=682
# Duplicidade encontrada para num_seq=332
# Duplicidade encontrada para num_seq=545
# Duplicidade encontrada para num_seq=430
# Inserção bem-sucedida para num_seq=76
# Inserção bem-sucedida para num_seq=114
# Duplicidade encontrada para num_seq=218
# Duplicidade encontrada para num_seq=374
# Duplicidade encontrada para num_seq=608
# Inserção bem-sucedida para num_seq=154
# Duplicidade encontrada para num_seq=561
# Duplicidade encontrada para num_seq=528
# Duplicidade encontrada para num_seq=148
# Duplicidade encontrada para num_seq=10
# Duplicidade encontrada para num_seq=681
# Inserção bem-sucedida para num_seq=586
# Duplicidade encontrada para num_seq=220
# Duplicidade encontrada para num_seq=287
# Duplicidade encontrada para num_seq=113
# Duplicidade encontrada para num_seq=497
# Inserção bem-sucedida para num_seq=109
# Duplicidade encontrada para num_seq=469
# Duplicidade encontrada para num_seq=337
# Duplicidade encontrada para num_seq=133
# Duplicidade encontrada para num_seq=553
# Duplicidade encontrada para num_seq=357
# Duplicidade encontrada para num_seq=613
# Duplicidade encontrada para num_seq=469
# Inserção bem-sucedida para num_seq=738
# Inserção bem-sucedida para num_seq=157
# Inserção bem-sucedida para num_seq=578
# Duplicidade encontrada para num_seq=366
# Duplicidade encontrada para num_seq=773
# Inserção bem-sucedida para num_seq=514
# Duplicidade encontrada para num_seq=499
# Duplicidade encontrada para num_seq=278
# Inserção bem-sucedida para num_seq=340
# Inserção bem-sucedida para num_seq=438
# Duplicidade encontrada para num_seq=345
# Duplicidade encontrada para num_seq=21
# Duplicidade encontrada para num_seq=343
# Inserção bem-sucedida para num_seq=796
# Duplicidade encontrada para num_seq=212
# Inserção bem-sucedida para num_seq=35
# Inserção bem-sucedida para num_seq=237
# Duplicidade encontrada para num_seq=169
# Duplicidade encontrada para num_seq=629
# Duplicidade encontrada para num_seq=255
# Duplicidade encontrada para num_seq=390
# Duplicidade encontrada para num_seq=655
# Duplicidade encontrada para num_seq=346
# Duplicidade encontrada para num_seq=377
# Duplicidade encontrada para num_seq=61
# Duplicidade encontrada para num_seq=717
# Duplicidade encontrada para num_seq=502
# Duplicidade encontrada para num_seq=252
# Duplicidade encontrada para num_seq=630
# Inserção bem-sucedida para num_seq=743
# Duplicidade encontrada para num_seq=244
# Duplicidade encontrada para num_seq=493
# Duplicidade encontrada para num_seq=608
# Duplicidade encontrada para num_seq=632
# Duplicidade encontrada para num_seq=100
# Inserção bem-sucedida para num_seq=22
# Duplicidade encontrada para num_seq=503
# Duplicidade encontrada para num_seq=586
# Duplicidade encontrada para num_seq=536
# Duplicidade encontrada para num_seq=476
# Duplicidade encontrada para num_seq=690
# Duplicidade encontrada para num_seq=427
# Duplicidade encontrada para num_seq=308
# Duplicidade encontrada para num_seq=764
# Duplicidade encontrada para num_seq=87
# Duplicidade encontrada para num_seq=319
# Duplicidade encontrada para num_seq=427
# Duplicidade encontrada para num_seq=104
# Duplicidade encontrada para num_seq=237
# Duplicidade encontrada para num_seq=50
# Duplicidade encontrada para num_seq=194
# Duplicidade encontrada para num_seq=48
# Duplicidade encontrada para num_seq=441
# Duplicidade encontrada para num_seq=257
# Duplicidade encontrada para num_seq=22
# Duplicidade encontrada para num_seq=104
# Duplicidade encontrada para num_seq=554
# Inserção bem-sucedida para num_seq=786
# Duplicidade encontrada para num_seq=693
# Duplicidade encontrada para num_seq=761
# Duplicidade encontrada para num_seq=367
# Duplicidade encontrada para num_seq=236
# Duplicidade encontrada para num_seq=214
# Duplicidade encontrada para num_seq=479
# Inserção bem-sucedida para num_seq=96
# Inserção bem-sucedida para num_seq=178
# Duplicidade encontrada para num_seq=346
# Duplicidade encontrada para num_seq=632
# Duplicidade encontrada para num_seq=503
# Duplicidade encontrada para num_seq=251
# Inserção bem-sucedida para num_seq=474
# Duplicidade encontrada para num_seq=681
# Duplicidade encontrada para num_seq=129
# Duplicidade encontrada para num_seq=795
# Inserção bem-sucedida para num_seq=196
# Duplicidade encontrada para num_seq=505
# Duplicidade encontrada para num_seq=532
# Duplicidade encontrada para num_seq=73
# Duplicidade encontrada para num_seq=541
# Duplicidade encontrada para num_seq=242
# Duplicidade encontrada para num_seq=420
# Duplicidade encontrada para num_seq=206
# Inserção bem-sucedida para num_seq=781
# Inserção bem-sucedida para num_seq=209
# Duplicidade encontrada para num_seq=711
# Duplicidade encontrada para num_seq=89
# Duplicidade encontrada para num_seq=641
# Duplicidade encontrada para num_seq=292
# Duplicidade encontrada para num_seq=156
# Duplicidade encontrada para num_seq=36
# Duplicidade encontrada para num_seq=171
# Inserção bem-sucedida para num_seq=601
# Duplicidade encontrada para num_seq=469
# Duplicidade encontrada para num_seq=544
# Duplicidade encontrada para num_seq=138
# Duplicidade encontrada para num_seq=82
# Duplicidade encontrada para num_seq=218
# Duplicidade encontrada para num_seq=238
# Duplicidade encontrada para num_seq=711
# Duplicidade encontrada para num_seq=450
# Duplicidade encontrada para num_seq=690
# Duplicidade encontrada para num_seq=724
# Duplicidade encontrada para num_seq=288
# Duplicidade encontrada para num_seq=149
# Duplicidade encontrada para num_seq=57
# Duplicidade encontrada para num_seq=582
# Duplicidade encontrada para num_seq=106
# Duplicidade encontrada para num_seq=354
# Duplicidade encontrada para num_seq=639
# Duplicidade encontrada para num_seq=769
# Inserção bem-sucedida para num_seq=86
# Inserção bem-sucedida para num_seq=361
# Duplicidade encontrada para num_seq=562
# Duplicidade encontrada para num_seq=141
# Inserção bem-sucedida para num_seq=391
# Duplicidade encontrada para num_seq=614
# Inserção bem-sucedida para num_seq=551
# Inserção bem-sucedida para num_seq=799
# Duplicidade encontrada para num_seq=573
# Duplicidade encontrada para num_seq=28
# Duplicidade encontrada para num_seq=741
# Duplicidade encontrada para num_seq=203
# Duplicidade encontrada para num_seq=21
# Duplicidade encontrada para num_seq=641
# Duplicidade encontrada para num_seq=513
# Inserção bem-sucedida para num_seq=518
# Inserção bem-sucedida para num_seq=297
# Duplicidade encontrada para num_seq=441
# Duplicidade encontrada para num_seq=271
# Duplicidade encontrada para num_seq=52
# Duplicidade encontrada para num_seq=413
# Inserção bem-sucedida para num_seq=405
# Duplicidade encontrada para num_seq=795
# Duplicidade encontrada para num_seq=211
# Duplicidade encontrada para num_seq=140
# Duplicidade encontrada para num_seq=669
# Duplicidade encontrada para num_seq=113
# Duplicidade encontrada para num_seq=161
# Duplicidade encontrada para num_seq=723
# Inserção bem-sucedida para num_seq=285
# Duplicidade encontrada para num_seq=128
# Duplicidade encontrada para num_seq=282
# Duplicidade encontrada para num_seq=278
# Inserção bem-sucedida para num_seq=98
# Duplicidade encontrada para num_seq=334
# Duplicidade encontrada para num_seq=503
# Duplicidade encontrada para num_seq=3
# Duplicidade encontrada para num_seq=692
# Duplicidade encontrada para num_seq=252
# Duplicidade encontrada para num_seq=223
# Inserção bem-sucedida para num_seq=492
# Duplicidade encontrada para num_seq=152
# Duplicidade encontrada para num_seq=250
# Duplicidade encontrada para num_seq=479
# Duplicidade encontrada para num_seq=116
# Duplicidade encontrada para num_seq=771
# Duplicidade encontrada para num_seq=497
# Duplicidade encontrada para num_seq=603
# Duplicidade encontrada para num_seq=17
# Duplicidade encontrada para num_seq=76
# Duplicidade encontrada para num_seq=274
# Duplicidade encontrada para num_seq=2
# Duplicidade encontrada para num_seq=522
# Duplicidade encontrada para num_seq=746
# Duplicidade encontrada para num_seq=745
# Duplicidade encontrada para num_seq=725
# Duplicidade encontrada para num_seq=53
# Duplicidade encontrada para num_seq=242
# Duplicidade encontrada para num_seq=494
# Inserção bem-sucedida para num_seq=207
# Duplicidade encontrada para num_seq=49
# Duplicidade encontrada para num_seq=755
# Duplicidade encontrada para num_seq=460
# Duplicidade encontrada para num_seq=774
# Inserção bem-sucedida para num_seq=631
# Duplicidade encontrada para num_seq=431
# Duplicidade encontrada para num_seq=456
# Duplicidade encontrada para num_seq=110
# Duplicidade encontrada para num_seq=158
# Duplicidade encontrada para num_seq=622
# Inserção bem-sucedida para num_seq=219
# Duplicidade encontrada para num_seq=58
# Duplicidade encontrada para num_seq=121
# Duplicidade encontrada para num_seq=377
# Inserção bem-sucedida para num_seq=115
# Duplicidade encontrada para num_seq=568
# Duplicidade encontrada para num_seq=168
# Duplicidade encontrada para num_seq=337
# Duplicidade encontrada para num_seq=594
# Duplicidade encontrada para num_seq=643
# Duplicidade encontrada para num_seq=684
# Duplicidade encontrada para num_seq=400
# Duplicidade encontrada para num_seq=667
# Inserção bem-sucedida para num_seq=706
# Inserção bem-sucedida para num_seq=350
# Duplicidade encontrada para num_seq=164
# Duplicidade encontrada para num_seq=120
# Duplicidade encontrada para num_seq=254
# Duplicidade encontrada para num_seq=100
# Duplicidade encontrada para num_seq=619
# Duplicidade encontrada para num_seq=652
# Duplicidade encontrada para num_seq=109
# Duplicidade encontrada para num_seq=486
# Duplicidade encontrada para num_seq=669
# Duplicidade encontrada para num_seq=564
# Duplicidade encontrada para num_seq=217
# Duplicidade encontrada para num_seq=350
# Duplicidade encontrada para num_seq=237
# Duplicidade encontrada para num_seq=2
# Inserção bem-sucedida para num_seq=404
# Duplicidade encontrada para num_seq=79
# Duplicidade encontrada para num_seq=723
# Duplicidade encontrada para num_seq=419
# Duplicidade encontrada para num_seq=593
# Duplicidade encontrada para num_seq=23
# Inserção bem-sucedida para num_seq=748
# Duplicidade encontrada para num_seq=352
# Duplicidade encontrada para num_seq=55
# Duplicidade encontrada para num_seq=58
# Duplicidade encontrada para num_seq=799
# Duplicidade encontrada para num_seq=231
# Duplicidade encontrada para num_seq=294
# Duplicidade encontrada para num_seq=447
# Duplicidade encontrada para num_seq=783
# Duplicidade encontrada para num_seq=578
# Duplicidade encontrada para num_seq=769
# Duplicidade encontrada para num_seq=174
# Duplicidade encontrada para num_seq=574
# Inserção bem-sucedida para num_seq=792
# Inserção bem-sucedida para num_seq=790
# Duplicidade encontrada para num_seq=19
# Duplicidade encontrada para num_seq=326
# Duplicidade encontrada para num_seq=629
# Duplicidade encontrada para num_seq=625
# Duplicidade encontrada para num_seq=607
# Inserção bem-sucedida para num_seq=700
# Inserção bem-sucedida para num_seq=611
# Duplicidade encontrada para num_seq=177
# Inserção bem-sucedida para num_seq=13
# Duplicidade encontrada para num_seq=653
# Duplicidade encontrada para num_seq=581
# Duplicidade encontrada para num_seq=377
# Duplicidade encontrada para num_seq=122
# Duplicidade encontrada para num_seq=258
# Duplicidade encontrada para num_seq=366
# Inserção bem-sucedida para num_seq=298
# Duplicidade encontrada para num_seq=188
# Duplicidade encontrada para num_seq=745
# Inserção bem-sucedida para num_seq=466
# Inserção bem-sucedida para num_seq=648
# Duplicidade encontrada para num_seq=550
# Duplicidade encontrada para num_seq=155
# Duplicidade encontrada para num_seq=545
# Duplicidade encontrada para num_seq=133
# Duplicidade encontrada para num_seq=358
# Duplicidade encontrada para num_seq=730
# Duplicidade encontrada para num_seq=341
# Duplicidade encontrada para num_seq=508
# Duplicidade encontrada para num_seq=97
# Duplicidade encontrada para num_seq=587
# Inserção bem-sucedida para num_seq=88
# Duplicidade encontrada para num_seq=43
# Inserção bem-sucedida para num_seq=777
# Duplicidade encontrada para num_seq=153
# Duplicidade encontrada para num_seq=368
# Duplicidade encontrada para num_seq=337
# Duplicidade encontrada para num_seq=250
# Duplicidade encontrada para num_seq=688
# Duplicidade encontrada para num_seq=719
# Duplicidade encontrada para num_seq=733
# Duplicidade encontrada para num_seq=789
# Duplicidade encontrada para num_seq=55
# Duplicidade encontrada para num_seq=701
# Duplicidade encontrada para num_seq=741
# Duplicidade encontrada para num_seq=236
# Duplicidade encontrada para num_seq=750
# Duplicidade encontrada para num_seq=19
# Duplicidade encontrada para num_seq=598
# Duplicidade encontrada para num_seq=496
# Duplicidade encontrada para num_seq=667

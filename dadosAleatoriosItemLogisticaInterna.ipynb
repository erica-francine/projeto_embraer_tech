# %%
from random import randint, choice
import mysql.connector

# %%
conexao = mysql.connector.connect(
    host='localhost',
    user='root',
    password='admin',
    database='custos_transporte'
)

# %%
cursor = conexao.cursor()

# Pegando todos os id_transferencia do MySQL da tabela logistica interna e armazenando em uma variável
cursor.execute("SELECT id_transferencia FROM logistica_interna")
logistica_interna = cursor.fetchall()

# Pegando todos os cod_materia_prima do MySQL da tabela materia_prima e armazenando em uma variável
cursor.execute("SELECT cod_materia_prima FROM materia_prima")
materia_prima = cursor.fetchall()

# Pegando todos os id_modelo do MySQL da tabela modelo_aviao e armazenando em uma variável
cursor.execute("SELECT id_aviao FROM producao_aviao")
producao_aviao = cursor.fetchall()

# %%
cursor = conexao.cursor()

# Função que vai gerar 800 registros aleatórios e inserir no MySQL na tabela item_logistica_interna
def logistica_interna_aleatorio():
    nums_seq_existentes = set()
      
    for _ in range(500):
        num_seq = randint(0, 800)
        
        while num_seq in nums_seq_existentes:
            num_seq = randint(0, 800)

            nums_seq_existentes.add(num_seq)
        quantidade = randint(5, 50)

        # Pegando IDs aleatórios das tabelas
        materia_prima_cod_materia_prima = choice(materia_prima)[0]
        logistica_interna_id_transferencia = choice(logistica_interna)[0]
        producao_aviao_id_aviao = choice(producao_aviao)[0]

        # Pegando IDs das tabelas materia_prima, logistica_interna, e modelo_aviao
        cursor.execute("SELECT cod_materia_prima FROM materia_prima WHERE cod_materia_prima = %s", (materia_prima_cod_materia_prima,))
        materia_prima_cod_materia_prima = cursor.fetchone()[0]
        
        cursor.execute("SELECT id_transferencia FROM logistica_interna WHERE id_transferencia = %s", (logistica_interna_id_transferencia,))
        logistica_interna_id_transferencia = cursor.fetchone()[0]

        cursor.execute("SELECT id_aviao FROM producao_aviao WHERE id_aviao = %s", (producao_aviao_id_aviao,))
        producao_aviao_id_aviao = cursor.fetchone()[0]

        # Inserindo dados na tabela
        try:
            insert_query = "INSERT INTO item_logistica_interna (num_seq, materia_prima_cod_materia_prima, logistica_interna_id_transferencia,  quantidade, producao_aviao_id_aviao) VALUES (%s, %s, %s, %s, %s);"
            data = (num_seq, materia_prima_cod_materia_prima, logistica_interna_id_transferencia,  quantidade, producao_aviao_id_aviao)
            cursor.execute(insert_query, data)

            conexao.commit()
    
            print(f"Inserção bem-sucedida para num_seq={num_seq}")
        except mysql.connector.Error as err:
                    if err.errno == mysql.connector.errorcode.ER_DUP_ENTRY:
                        print(f"Duplicidade encontrada para num_seq={num_seq}")
                    else:
                        print(f"Erro ao inserir: {err}")

# Chamando a função para gerar os registros
logistica_interna_aleatorio()

# Fechando a conexão
cursor.close()
conexao.close()
# Out:
# Inserção bem-sucedida para num_seq=417
# Inserção bem-sucedida para num_seq=238
# Inserção bem-sucedida para num_seq=132
# Inserção bem-sucedida para num_seq=83
# Inserção bem-sucedida para num_seq=252
# Inserção bem-sucedida para num_seq=359
# Inserção bem-sucedida para num_seq=5
# Inserção bem-sucedida para num_seq=644
# Inserção bem-sucedida para num_seq=48
# Inserção bem-sucedida para num_seq=303
# Inserção bem-sucedida para num_seq=434
# Inserção bem-sucedida para num_seq=100
# Inserção bem-sucedida para num_seq=544
# Inserção bem-sucedida para num_seq=73
# Inserção bem-sucedida para num_seq=477
# Inserção bem-sucedida para num_seq=351
# Inserção bem-sucedida para num_seq=657
# Inserção bem-sucedida para num_seq=654
# Inserção bem-sucedida para num_seq=702
# Inserção bem-sucedida para num_seq=2
# Inserção bem-sucedida para num_seq=393
# Inserção bem-sucedida para num_seq=256
# Inserção bem-sucedida para num_seq=236
# Inserção bem-sucedida para num_seq=38
# Inserção bem-sucedida para num_seq=149
# Inserção bem-sucedida para num_seq=155
# Inserção bem-sucedida para num_seq=277
# Inserção bem-sucedida para num_seq=294
# Inserção bem-sucedida para num_seq=296
# Inserção bem-sucedida para num_seq=350
# Inserção bem-sucedida para num_seq=58
# Inserção bem-sucedida para num_seq=758
# Inserção bem-sucedida para num_seq=194
# Inserção bem-sucedida para num_seq=90
# Inserção bem-sucedida para num_seq=103
# Inserção bem-sucedida para num_seq=371
# Inserção bem-sucedida para num_seq=731
# Inserção bem-sucedida para num_seq=629
# Inserção bem-sucedida para num_seq=333
# Inserção bem-sucedida para num_seq=650
# Inserção bem-sucedida para num_seq=626
# Inserção bem-sucedida para num_seq=395
# Inserção bem-sucedida para num_seq=674
# Inserção bem-sucedida para num_seq=581
# Inserção bem-sucedida para num_seq=358
# Inserção bem-sucedida para num_seq=621
# Inserção bem-sucedida para num_seq=554
# Inserção bem-sucedida para num_seq=27
# Inserção bem-sucedida para num_seq=429
# Inserção bem-sucedida para num_seq=553
# Inserção bem-sucedida para num_seq=398
# Inserção bem-sucedida para num_seq=771
# Inserção bem-sucedida para num_seq=596
# Inserção bem-sucedida para num_seq=669
# Inserção bem-sucedida para num_seq=503
# Inserção bem-sucedida para num_seq=239
# Inserção bem-sucedida para num_seq=228
# Inserção bem-sucedida para num_seq=384
# Duplicidade encontrada para num_seq=239
# Inserção bem-sucedida para num_seq=401
# Duplicidade encontrada para num_seq=303
# Inserção bem-sucedida para num_seq=191
# Duplicidade encontrada para num_seq=5
# Inserção bem-sucedida para num_seq=614
# Inserção bem-sucedida para num_seq=794
# Duplicidade encontrada para num_seq=503
# Inserção bem-sucedida para num_seq=740
# Inserção bem-sucedida para num_seq=177
# Inserção bem-sucedida para num_seq=1
# Inserção bem-sucedida para num_seq=481
# Inserção bem-sucedida para num_seq=158
# Inserção bem-sucedida para num_seq=297
# Inserção bem-sucedida para num_seq=617
# Inserção bem-sucedida para num_seq=756
# Inserção bem-sucedida para num_seq=559
# Inserção bem-sucedida para num_seq=414
# Inserção bem-sucedida para num_seq=255
# Inserção bem-sucedida para num_seq=373
# Inserção bem-sucedida para num_seq=456
# Inserção bem-sucedida para num_seq=411
# Inserção bem-sucedida para num_seq=410
# Inserção bem-sucedida para num_seq=316
# Inserção bem-sucedida para num_seq=266
# Duplicidade encontrada para num_seq=38
# Duplicidade encontrada para num_seq=350
# Inserção bem-sucedida para num_seq=691
# Inserção bem-sucedida para num_seq=422
# Duplicidade encontrada para num_seq=132
# Inserção bem-sucedida para num_seq=783
# Inserção bem-sucedida para num_seq=213
# Inserção bem-sucedida para num_seq=50
# Inserção bem-sucedida para num_seq=285
# Duplicidade encontrada para num_seq=255
# Inserção bem-sucedida para num_seq=131
# Duplicidade encontrada para num_seq=294
# Inserção bem-sucedida para num_seq=737
# Duplicidade encontrada para num_seq=384
# Inserção bem-sucedida para num_seq=578
# Inserção bem-sucedida para num_seq=696
# Inserção bem-sucedida para num_seq=516
# Inserção bem-sucedida para num_seq=124
# Inserção bem-sucedida para num_seq=326
# Inserção bem-sucedida para num_seq=12
# Inserção bem-sucedida para num_seq=229
# Inserção bem-sucedida para num_seq=93
# Inserção bem-sucedida para num_seq=227
# Inserção bem-sucedida para num_seq=142
# Duplicidade encontrada para num_seq=194
# Inserção bem-sucedida para num_seq=180
# Inserção bem-sucedida para num_seq=89
# Inserção bem-sucedida para num_seq=800
# Inserção bem-sucedida para num_seq=444
# Inserção bem-sucedida para num_seq=757
# Inserção bem-sucedida para num_seq=209
# Inserção bem-sucedida para num_seq=689
# Inserção bem-sucedida para num_seq=36
# Duplicidade encontrada para num_seq=794
# Inserção bem-sucedida para num_seq=300
# Duplicidade encontrada para num_seq=669
# Duplicidade encontrada para num_seq=285
# Inserção bem-sucedida para num_seq=792
# Inserção bem-sucedida para num_seq=110
# Duplicidade encontrada para num_seq=393
# Inserção bem-sucedida para num_seq=92
# Inserção bem-sucedida para num_seq=698
# Inserção bem-sucedida para num_seq=526
# Inserção bem-sucedida para num_seq=706
# Inserção bem-sucedida para num_seq=145
# Inserção bem-sucedida para num_seq=17
# Inserção bem-sucedida para num_seq=249
# Inserção bem-sucedida para num_seq=426
# Inserção bem-sucedida para num_seq=561
# Inserção bem-sucedida para num_seq=219
# Inserção bem-sucedida para num_seq=511
# Inserção bem-sucedida para num_seq=39
# Duplicidade encontrada para num_seq=614
# Inserção bem-sucedida para num_seq=87
# Inserção bem-sucedida para num_seq=388
# Inserção bem-sucedida para num_seq=687
# Inserção bem-sucedida para num_seq=663
# Inserção bem-sucedida para num_seq=281
# Duplicidade encontrada para num_seq=296
# Inserção bem-sucedida para num_seq=772
# Inserção bem-sucedida para num_seq=778
# Inserção bem-sucedida para num_seq=234
# Inserção bem-sucedida para num_seq=14
# Inserção bem-sucedida para num_seq=700
# Inserção bem-sucedida para num_seq=620
# Duplicidade encontrada para num_seq=687
# Duplicidade encontrada para num_seq=614
# Inserção bem-sucedida para num_seq=743
# Duplicidade encontrada para num_seq=422
# Inserção bem-sucedida para num_seq=272
# Duplicidade encontrada para num_seq=177
# Inserção bem-sucedida para num_seq=306
# Inserção bem-sucedida para num_seq=796
# Inserção bem-sucedida para num_seq=159
# Duplicidade encontrada para num_seq=434
# Inserção bem-sucedida para num_seq=279
# Inserção bem-sucedida para num_seq=761
# Duplicidade encontrada para num_seq=2
# Inserção bem-sucedida para num_seq=609
# Inserção bem-sucedida para num_seq=254
# Inserção bem-sucedida para num_seq=75
# Inserção bem-sucedida para num_seq=492
# Inserção bem-sucedida para num_seq=798
# Inserção bem-sucedida para num_seq=701
# Inserção bem-sucedida para num_seq=499
# Inserção bem-sucedida para num_seq=385
# Inserção bem-sucedida para num_seq=506
# Inserção bem-sucedida para num_seq=655
# Inserção bem-sucedida para num_seq=692
# Inserção bem-sucedida para num_seq=419
# Inserção bem-sucedida para num_seq=31
# Inserção bem-sucedida para num_seq=235
# Inserção bem-sucedida para num_seq=369
# Inserção bem-sucedida para num_seq=183
# Inserção bem-sucedida para num_seq=246
# Inserção bem-sucedida para num_seq=30
# Inserção bem-sucedida para num_seq=126
# Duplicidade encontrada para num_seq=294
# Inserção bem-sucedida para num_seq=428
# Duplicidade encontrada para num_seq=617
# Inserção bem-sucedida para num_seq=188
# Inserção bem-sucedida para num_seq=580
# Inserção bem-sucedida para num_seq=40
# Duplicidade encontrada para num_seq=792
# Inserção bem-sucedida para num_seq=53
# Inserção bem-sucedida para num_seq=638
# Inserção bem-sucedida para num_seq=699
# Inserção bem-sucedida para num_seq=233
# Inserção bem-sucedida para num_seq=154
# Inserção bem-sucedida para num_seq=59
# Inserção bem-sucedida para num_seq=317
# Duplicidade encontrada para num_seq=145
# Inserção bem-sucedida para num_seq=486
# Inserção bem-sucedida para num_seq=95
# Inserção bem-sucedida para num_seq=332
# Inserção bem-sucedida para num_seq=163
# Duplicidade encontrada para num_seq=388
# Inserção bem-sucedida para num_seq=399
# Duplicidade encontrada para num_seq=163
# Duplicidade encontrada para num_seq=213
# Inserção bem-sucedida para num_seq=710
# Inserção bem-sucedida para num_seq=527
# Inserção bem-sucedida para num_seq=682
# Inserção bem-sucedida para num_seq=684
# Inserção bem-sucedida para num_seq=571
# Inserção bem-sucedida para num_seq=519
# Inserção bem-sucedida para num_seq=184
# Inserção bem-sucedida para num_seq=711
# Inserção bem-sucedida para num_seq=535
# Inserção bem-sucedida para num_seq=206
# Inserção bem-sucedida para num_seq=438
# Inserção bem-sucedida para num_seq=541
# Inserção bem-sucedida para num_seq=589
# Inserção bem-sucedida para num_seq=324
# Inserção bem-sucedida para num_seq=162
# Inserção bem-sucedida para num_seq=550
# Inserção bem-sucedida para num_seq=449
# Inserção bem-sucedida para num_seq=556
# Duplicidade encontrada para num_seq=132
# Inserção bem-sucedida para num_seq=278
# Inserção bem-sucedida para num_seq=508
# Inserção bem-sucedida para num_seq=555
# Inserção bem-sucedida para num_seq=181
# Duplicidade encontrada para num_seq=236
# Inserção bem-sucedida para num_seq=267
# Inserção bem-sucedida para num_seq=187
# Inserção bem-sucedida para num_seq=211
# Inserção bem-sucedida para num_seq=637
# Duplicidade encontrada para num_seq=149
# Inserção bem-sucedida para num_seq=675
# Inserção bem-sucedida para num_seq=21
# Inserção bem-sucedida para num_seq=367
# Inserção bem-sucedida para num_seq=334
# Duplicidade encontrada para num_seq=434
# Inserção bem-sucedida para num_seq=216
# Inserção bem-sucedida para num_seq=625
# Inserção bem-sucedida para num_seq=505
# Duplicidade encontrada para num_seq=556
# Inserção bem-sucedida para num_seq=150
# Inserção bem-sucedida para num_seq=298
# Inserção bem-sucedida para num_seq=148
# Inserção bem-sucedida para num_seq=784
# Inserção bem-sucedida para num_seq=450
# Duplicidade encontrada para num_seq=358
# Duplicidade encontrada para num_seq=388
# Inserção bem-sucedida para num_seq=530
# Inserção bem-sucedida para num_seq=775
# Inserção bem-sucedida para num_seq=464
# Duplicidade encontrada para num_seq=158
# Inserção bem-sucedida para num_seq=394
# Inserção bem-sucedida para num_seq=109
# Inserção bem-sucedida para num_seq=746
# Duplicidade encontrada para num_seq=650
# Inserção bem-sucedida para num_seq=287
# Inserção bem-sucedida para num_seq=192
# Inserção bem-sucedida para num_seq=725
# Inserção bem-sucedida para num_seq=611
# Inserção bem-sucedida para num_seq=636
# Inserção bem-sucedida para num_seq=431
# Inserção bem-sucedida para num_seq=496
# Inserção bem-sucedida para num_seq=604
# Duplicidade encontrada para num_seq=395
# Duplicidade encontrada para num_seq=796
# Duplicidade encontrada para num_seq=506
# Duplicidade encontrada para num_seq=154
# Duplicidade encontrada para num_seq=431
# Duplicidade encontrada para num_seq=636
# Duplicidade encontrada para num_seq=1
# Inserção bem-sucedida para num_seq=607
# Inserção bem-sucedida para num_seq=478
# Inserção bem-sucedida para num_seq=321
# Inserção bem-sucedida para num_seq=340
# Duplicidade encontrada para num_seq=100
# Inserção bem-sucedida para num_seq=335
# Duplicidade encontrada para num_seq=614
# Inserção bem-sucedida para num_seq=157
# Inserção bem-sucedida para num_seq=151
# Inserção bem-sucedida para num_seq=400
# Duplicidade encontrada para num_seq=369
# Inserção bem-sucedida para num_seq=261
# Inserção bem-sucedida para num_seq=237
# Duplicidade encontrada para num_seq=321
# Inserção bem-sucedida para num_seq=704
# Inserção bem-sucedida para num_seq=347
# Inserção bem-sucedida para num_seq=770
# Inserção bem-sucedida para num_seq=46
# Inserção bem-sucedida para num_seq=717
# Inserção bem-sucedida para num_seq=563
# Duplicidade encontrada para num_seq=505
# Inserção bem-sucedida para num_seq=685
# Inserção bem-sucedida para num_seq=230
# Inserção bem-sucedida para num_seq=642
# Inserção bem-sucedida para num_seq=634
# Inserção bem-sucedida para num_seq=721
# Duplicidade encontrada para num_seq=609
# Inserção bem-sucedida para num_seq=763
# Inserção bem-sucedida para num_seq=755
# Inserção bem-sucedida para num_seq=442
# Inserção bem-sucedida para num_seq=730
# Inserção bem-sucedida para num_seq=635
# Inserção bem-sucedida para num_seq=493
# Inserção bem-sucedida para num_seq=276
# Inserção bem-sucedida para num_seq=353
# Inserção bem-sucedida para num_seq=498
# Duplicidade encontrada para num_seq=235
# Inserção bem-sucedida para num_seq=322
# Inserção bem-sucedida para num_seq=639
# Inserção bem-sucedida para num_seq=782
# Duplicidade encontrada para num_seq=783
# Inserção bem-sucedida para num_seq=218
# Inserção bem-sucedida para num_seq=664
# Inserção bem-sucedida para num_seq=452
# Inserção bem-sucedida para num_seq=517
# Inserção bem-sucedida para num_seq=522
# Inserção bem-sucedida para num_seq=339
# Inserção bem-sucedida para num_seq=789
# Inserção bem-sucedida para num_seq=82
# Inserção bem-sucedida para num_seq=337
# Inserção bem-sucedida para num_seq=108
# Duplicidade encontrada para num_seq=40
# Inserção bem-sucedida para num_seq=232
# Inserção bem-sucedida para num_seq=579
# Duplicidade encontrada para num_seq=792
# Inserção bem-sucedida para num_seq=475
# Inserção bem-sucedida para num_seq=739
# Inserção bem-sucedida para num_seq=81
# Inserção bem-sucedida para num_seq=513
# Inserção bem-sucedida para num_seq=648
# Inserção bem-sucedida para num_seq=259
# Inserção bem-sucedida para num_seq=518
# Inserção bem-sucedida para num_seq=160
# Inserção bem-sucedida para num_seq=427
# Inserção bem-sucedida para num_seq=323
# Duplicidade encontrada para num_seq=150
# Inserção bem-sucedida para num_seq=547
# Duplicidade encontrada para num_seq=663
# Duplicidade encontrada para num_seq=794
# Duplicidade encontrada para num_seq=554
# Inserção bem-sucedida para num_seq=507
# Duplicidade encontrada para num_seq=184
# Duplicidade encontrada para num_seq=159
# Inserção bem-sucedida para num_seq=616
# Inserção bem-sucedida para num_seq=653
# Inserção bem-sucedida para num_seq=509
# Inserção bem-sucedida para num_seq=205
# Inserção bem-sucedida para num_seq=201
# Inserção bem-sucedida para num_seq=262
# Inserção bem-sucedida para num_seq=208
# Inserção bem-sucedida para num_seq=768
# Duplicidade encontrada para num_seq=663
# Inserção bem-sucedida para num_seq=128
# Inserção bem-sucedida para num_seq=630
# Duplicidade encontrada para num_seq=431
# Inserção bem-sucedida para num_seq=80
# Duplicidade encontrada para num_seq=669
# Inserção bem-sucedida para num_seq=129
# Inserção bem-sucedida para num_seq=9
# Inserção bem-sucedida para num_seq=708
# Inserção bem-sucedida para num_seq=471
# Inserção bem-sucedida para num_seq=406
# Inserção bem-sucedida para num_seq=413
# Inserção bem-sucedida para num_seq=799
# Inserção bem-sucedida para num_seq=791
# Inserção bem-sucedida para num_seq=69
# Duplicidade encontrada para num_seq=351
# Duplicidade encontrada para num_seq=413
# Inserção bem-sucedida para num_seq=425
# Inserção bem-sucedida para num_seq=534
# Inserção bem-sucedida para num_seq=56
# Inserção bem-sucedida para num_seq=84
# Duplicidade encontrada para num_seq=438
# Inserção bem-sucedida para num_seq=591
# Duplicidade encontrada para num_seq=298
# Inserção bem-sucedida para num_seq=584
# Duplicidade encontrada para num_seq=2
# Duplicidade encontrada para num_seq=782
# Inserção bem-sucedida para num_seq=576
# Inserção bem-sucedida para num_seq=407
# Inserção bem-sucedida para num_seq=231
# Duplicidade encontrada para num_seq=213
# Inserção bem-sucedida para num_seq=602
# Duplicidade encontrada para num_seq=450
# Inserção bem-sucedida para num_seq=586
# Inserção bem-sucedida para num_seq=19
# Inserção bem-sucedida para num_seq=632
# Inserção bem-sucedida para num_seq=309
# Inserção bem-sucedida para num_seq=437
# Inserção bem-sucedida para num_seq=780
# Duplicidade encontrada para num_seq=755
# Inserção bem-sucedida para num_seq=55
# Duplicidade encontrada para num_seq=228
# Inserção bem-sucedida para num_seq=601
# Inserção bem-sucedida para num_seq=114
# Duplicidade encontrada para num_seq=702
# Inserção bem-sucedida para num_seq=127
# Inserção bem-sucedida para num_seq=123
# Inserção bem-sucedida para num_seq=457
# Duplicidade encontrada para num_seq=481
# Inserção bem-sucedida para num_seq=173
# Inserção bem-sucedida para num_seq=680
# Inserção bem-sucedida para num_seq=649
# Inserção bem-sucedida para num_seq=606
# Duplicidade encontrada para num_seq=332
# Duplicidade encontrada para num_seq=219
# Inserção bem-sucedida para num_seq=182
# Duplicidade encontrada para num_seq=132
# Inserção bem-sucedida para num_seq=525
# Inserção bem-sucedida para num_seq=728
# Duplicidade encontrada para num_seq=150
# Inserção bem-sucedida para num_seq=99
# Inserção bem-sucedida para num_seq=391
# Inserção bem-sucedida para num_seq=270
# Duplicidade encontrada para num_seq=571
# Inserção bem-sucedida para num_seq=167
# Inserção bem-sucedida para num_seq=660
# Inserção bem-sucedida para num_seq=409
# Duplicidade encontrada para num_seq=230
# Inserção bem-sucedida para num_seq=196
# Duplicidade encontrada para num_seq=321
# Inserção bem-sucedida para num_seq=777
# Inserção bem-sucedida para num_seq=336
# Inserção bem-sucedida para num_seq=338
# Inserção bem-sucedida para num_seq=356
# Inserção bem-sucedida para num_seq=575
# Inserção bem-sucedida para num_seq=754
# Duplicidade encontrada para num_seq=194
# Duplicidade encontrada para num_seq=486
# Inserção bem-sucedida para num_seq=113
# Inserção bem-sucedida para num_seq=275
# Duplicidade encontrada para num_seq=192
# Duplicidade encontrada para num_seq=761
# Duplicidade encontrada para num_seq=9
# Inserção bem-sucedida para num_seq=718
# Duplicidade encontrada para num_seq=444
# Duplicidade encontrada para num_seq=772
# Inserção bem-sucedida para num_seq=673
# Duplicidade encontrada para num_seq=31
# Duplicidade encontrada para num_seq=277
# Duplicidade encontrada para num_seq=799
# Duplicidade encontrada para num_seq=650
# Inserção bem-sucedida para num_seq=672
# Duplicidade encontrada para num_seq=385
# Inserção bem-sucedida para num_seq=283
# Duplicidade encontrada para num_seq=796
# Duplicidade encontrada para num_seq=475
# Duplicidade encontrada para num_seq=438
# Inserção bem-sucedida para num_seq=366
# Inserção bem-sucedida para num_seq=667
# Duplicidade encontrada para num_seq=731
# Duplicidade encontrada para num_seq=180
# Duplicidade encontrada para num_seq=281
# Inserção bem-sucedida para num_seq=61
# Duplicidade encontrada para num_seq=437
# Inserção bem-sucedida para num_seq=618
# Inserção bem-sucedida para num_seq=588
# Inserção bem-sucedida para num_seq=705
# Inserção bem-sucedida para num_seq=98
# Inserção bem-sucedida para num_seq=722
# Duplicidade encontrada para num_seq=114
# Inserção bem-sucedida para num_seq=210
# Inserção bem-sucedida para num_seq=8
# Duplicidade encontrada para num_seq=768
# Inserção bem-sucedida para num_seq=289
# Duplicidade encontrada para num_seq=235
# Inserção bem-sucedida para num_seq=472
# Inserção bem-sucedida para num_seq=646
# Inserção bem-sucedida para num_seq=537
# Duplicidade encontrada para num_seq=256
# Duplicidade encontrada para num_seq=218
# Inserção bem-sucedida para num_seq=293
# Inserção bem-sucedida para num_seq=468
# Duplicidade encontrada para num_seq=780
# Inserção bem-sucedida para num_seq=106
# Inserção bem-sucedida para num_seq=622
# Duplicidade encontrada para num_seq=754
# Inserção bem-sucedida para num_seq=668
# Duplicidade encontrada para num_seq=428
# Duplicidade encontrada para num_seq=691
# Duplicidade encontrada para num_seq=672
# Duplicidade encontrada para num_seq=646
# Duplicidade encontrada para num_seq=300
# Duplicidade encontrada para num_seq=89
# Inserção bem-sucedida para num_seq=408
# Inserção bem-sucedida para num_seq=564
# Duplicidade encontrada para num_seq=493
# Inserção bem-sucedida para num_seq=172
# Inserção bem-sucedida para num_seq=136
# Inserção bem-sucedida para num_seq=597
# Duplicidade encontrada para num_seq=262
# Duplicidade encontrada para num_seq=449
# Inserção bem-sucedida para num_seq=386
# Duplicidade encontrada para num_seq=428
# Inserção bem-sucedida para num_seq=788
# Duplicidade encontrada para num_seq=698
# Inserção bem-sucedida para num_seq=49
# Duplicidade encontrada para num_seq=400
# Duplicidade encontrada para num_seq=317
